# %% [markdown]
# ## Topic Modeling (LDA) ##
#
# ### LDA :- Latent Dirichlet Allocation Model/Algorithm ###
#
# #### By Vedant Lotia ####

# %%
import gensim
import wikipedia
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
basketball = wikipedia.page('Basketball')
politics = wikipedia.page('Politics')
astronomy = wikipedia.page('Astronomy')
cricket = wikipedia.page('Cricket')
animals = wikipedia.page('Animals')
biology = wikipedia.page('Biology')
neuroscience = wikipedia.page('Neuroscience')
film = wikipedia.page('Film')
money = wikipedia.page('Money')

# %%
film.content
# Out:
# 'A film, also called a movie, motion picture or moving picture, is a work of visual art that simulates experiences and otherwise communicates ideas, stories, perceptions, feelings, beauty, or atmosphere through the use of moving images. These images are generally accompanied by sound, and more rarely, other sensory stimulations. The word "cinema", short for cinematography, is often used to refer to filmmaking and the film industry, and to the art form that is the result of it.\n\n\n== Recording and transmission of film ==\nThe moving images of a film are created by photographing actual scenes with a motion-picture camera, by photographing drawings or miniature models using traditional animation techniques, by means of CGI and computer animation, or by a combination of some or all of these techniques, and other visual effects.\nBefore the introduction of digital production, series of still images were recorded on a strip of chemically sensitized celluloid (photographic film stock), usually at the rate of 24 frames per second. The images are transmitted through a movie projector at the same rate as they were recorded, with a Geneva drive ensuring that each frame remains still during its short projection time. A rotating shutter causes stroboscopic intervals of darkness, but the viewer does not notice the interruptions due to flicker fusion. The apparent motion on the screen is the result of the fact that the visual sense cannot discern the individual images at high speeds, so the impressions of the images blend with the dark intervals and are thus linked together to produce the illusion of one moving image. An analogous optical soundtrack (a graphic recording of the spoken words, music and other sounds) runs along a portion of the film exclusively reserved for it, and was not projected.  \nContemporary films are usually fully digital  through the entire process of production, distribution, and exhibition.\n\n\n== Etymology ==\nThe name "film" originally referred to the thin layer of photochemical emulsion on the celluloid strip that used to be the actual medium for recording and displaying motion pictures. \nMany other terms exist for an individual motion-picture, including picture, picture show, moving picture, photoplay, and flick. The most common term in the United States is movie, while in Europe film is preferred. Archaic terms include "animated pictures" and "animated photography".\nCommon terms for the field in general include the big screen, the silver screen, the movies, and cinema; the last of these is commonly used, as an overarching term, in scholarly texts and critical essays. In early years, the word sheet was sometimes used instead of screen.\n\n\n== History ==\n\n\n=== Precursors ===\nThe art of film has drawn on several earlier traditions in fields such as oral storytelling, literature, theatre and visual arts. Forms of art and entertainment that had already featured moving and/or projected images include:\n\nshadowgraphy, probably used since prehistoric times\ncamera obscura, a natural phenomenon that has possibly been used as an artistic aid since prehistoric times\nshadow puppetry, possibly originated around 200 BCE in Central Asia, India, Indonesia or China\nThe magic lantern, developed in the 1650s. The multi-media phantasmagoria shows that utilized magic lanterns were popular from 1790 throughout the first half of the 19th century and could feature mechanical slides, rear projection, mobile projectors, superimposition, dissolving views, live actors, smoke (sometimes to project images upon), odors, sounds and even electric shocks.\n\n\n=== Before celluloid ===\n\nThe stroboscopic animation principle was introduced in 1833 with the stroboscopic disc (better known as the phénakisticope) and later applied in the zoetrope (since 1866), the flip book (since 1868), and the praxinoscope (since 1877), before it became the basic principle for cinematography.\nExperiments with early phénakisticope-based animation pro ...

# %%
corpus = [basketball.content,politics.content,astronomy.content,cricket.content,animals.content,biology.content,neuroscience.content,film.content,money.content]
len(corpus)
# Out:
# 9

# %% [markdown]
# ## Pre-processing ##

# %%
import re
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
stemmer = WordNetLemmatizer()

def preprocess_text(document):
    
    document = re.sub(r'\W',' ', str(document)) ## Removing Special Characters ##
    
    document = re.sub(r'\s+[a-zA-Z]\s+',' ', document) ## Removing all single Characters ##
    
    document = re.sub(r'\^[a-zA-Z]\s+',' ', document) ## Removing single Characters from start ##
    
    document = re.sub(r'\s+',' ',document, flags=re.I) ## Removing Special CharactersSubstituting multiple space with single space ##
     
    document = re.sub(r'^b\s',' ', document) ## Removing prefixed 'b' ##
    
    document = document.lower() ## Converting to lower cases ##
    
    tokens = document.split()
    tokens = [stemmer.lemmatize(word) for word in tokens]
    tokens = [word for word in tokens if word not in en_stop]
    tokens = [word for word in tokens if len(word) > 5]
    
    return tokens

processed_data = [];
for doc in corpus:
    tokens = preprocess_text(doc)
    processed_data.append(tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
processed_data[0:100]
# Out:
# [['baseball',
#   'played',
#   'opposing',
#   'player',
#   'batting',
#   'fielding',
#   'proceeds',
#   'player',
#   'fielding',
#   'called',
#   'pitcher',
#   'player',
#   'batting',
#   'objective',
#   'offensive',
#   'batting',
#   'allowing',
#   'player',
#   'advance',
#   'counter',
#   'clockwise',
#   'around',
#   'called',
#   'objective',
#   'defensive',
#   'fielding',
#   'prevent',
#   'batter',
#   'becoming',
#   'runner',
#   'prevent',
#   'runner',
#   'advance',
#   'around',
#   'scored',
#   'runner',
#   'legally',
#   'advance',
#   'around',
#   'player',
#   'started',
#   'batter',
#   'winner',
#   'objective',
#   'batting',
#   'player',
#   'safely',
#   'player',
#   'batting',
#   'without',
#   'called',
#   'attempt',
#   'advance',
#   'subsequent',
#   'runner',
#   'either',
#   'immediately',
#   'teammate',
#   'batting',
#   'fielding',
#   'prevent',
#   'getting',
#   'batter',
#   'runner',
#   'pitcher',
#   'fielder',
#   'method',
#   'getting',
#   'batting',
#   'player',
#   'opposing',
#   'switch',
#   'batting',
#   'fielding',
#   'batting',
#   'fielding',
#   'record',
#   'batting',
#   'constitutes',
#   'inning',
#   'usually',
#   'composed',
#   'inning',
#   'greater',
#   'number',
#   'inning',
#   'inning',
#   'usually',
#   'played',
#   'baseball',
#   'although',
#   'inning',
#   'baseball',
#   'evolved',
#   'already',
#   'played',
#   'england',
#   'century',
#   'brought',
#   'immigrant',
#   'america',
#   'modern',
#   'version',
#   'developed',
#   'century',
#   'baseball',
#   'widely',
#   'recognized',
#   'national',
#   'united',
#   'baseball',
#   'popular',
#   'america',
#   'central',
#   'america',
#   'caribbean',
#   'particularly',
#   'taiwan',
#   'united',
#   'canada',
#   'professional',
#   'league',
#   'baseball',
#   'divided',
#   'national',
#   'league',
#   'american',
#   'league',
#   'division',
#   'central',
#   'champion',
#   'determined',
#   'playoff',
#   'culminate',
#   'series',
#   'similarly',
#   'central',
#   'pacific',
#   'league',
#   'league',
#   'league',
#   'baseball',
#   'classic',
#   'organized',
#   'baseball',
#   'softball',
#   'confederation',
#   'international',
#   'competition',
#   'attracts',
#   'national',
#   'around',
#   'gameplay',
#   'baseball',
#   'played',
#   'usually',
#   'composed',
#   'player',
#   'playing',
#   'offense',
#   'batting',
#   'baserunning',
#   'defense',
#   'pitching',
#   'fielding',
#   'constitutes',
#   'inning',
#   'consists',
#   'inning',
#   'inning',
#   'school',
#   'doubleheader',
#   'college',
#   'league',
#   'baseball',
#   'season',
#   'league',
#   'baseball',
#   'inning',
#   'little',
#   'league',
#   'customarily',
#   'visiting',
#   'inning',
#   'customarily',
#   'bottom',
#   'second',
#   'inning',
#   'player',
#   'attempt',
#   'touching',
#   'corner',
#   'square',
#   'shaped',
#   'baseball',
#   'diamond',
#   'player',
#   'attempt',
#   'safely',
#   'proceeding',
#   'counterclockwise',
#   'second',
#   'attempt',
#   'prevent',
#   'scoring',
#   'recording',
#   'remove',
#   'opposing',
#   'player',
#   'offensive',
#   'action',
#   'recorded',
#   'switch',
#   'inning',
#   'inning',
#   'inning',
#   'played',
#   'resolve',
#   'contest',
#   'amateur',
#   'particularly',
#   'unorganized',
#   'involve',
#   'different',
#   'number',
#   'player',
#   'inning',
#   'played',
#   'primary',
#   'boundary',
#   'extend',
#   'forward',
#   'degree',
#   'degree',
#   'within',
#   'referred',
#   'territory',
#   'degree',
#   'outside',
#   'territory',
#   'enclosed',
#   'several',
#   'beyond',
#   'infield',
#   'farther',
#   'beyond',
#   'infield',
#   'outfield',
#   'middle',
#   'infield',
#   'raised',
#   'pitcher',
#   'rectangular',
#   'rubber',
#   'rubber',
#   'center',
#   'boundary',
#   'outfield',
#   'typically',
#   'demarcated',
#   'raised',
#   'material',
#   'height',
#   'territory',
#   'outfield',
#   'boundary',
#   'baseball',
#   'though',
#   'significant',
#   'territory',
#   'baseball',
#   'baseball',
#   'around',
#   'centimeter',
#   'circumference',
#   'rubber',
#   'center',
#   'covered',
#   'cowhide',
#   'stitching',
#   'hitting',
#   'traditionally',
#   'single',
#   'material',
#   'commonly',
#   'nonprofessional',
#   'centimeter',
#   'diameter',
#   'hitting',
#   'tapering',
#   'narrower',
#   'handle',
#   'culminating',
#   'typically',
#   'around',
#   'centimeter',
#   'longer',
#   'centimeter',
#   'fielding',
#   'padded',
#   'leather',
#   'webbing',
#   'finger',
#   'catching',
#   'holding',
#   'various',
#   'specific',
#   'different',
#   'fielding',
#   'position',
#   'protective',
#   'helmet',
#   'standard',
#   'equipment',
#   'batter',
#   'beginning',
#   'inning',
#   'player',
#   'fielding',
#   'arrange',
#   'around',
#   'pitcher',
#   'pitcher',
#   'pitcher',
#   'pitching',
#   'delivery',
#   'rubber',
#   'pushing',
#   'velocity',
#   'throwing',
#   'toward',
#   'another',
#   'fielding',
#   'player',
#   'catcher',
#   'facing',
#   'pitcher',
#   'fielding',
#   'typically',
#   'arranged',
#   'infielder',
#   'within',
#   'outside',
#   'imaginary',
#   'basepaths',
#   'second',
#   'outfielder',
#   'standard',
#   'arrangement',
#   'baseman',
#   'positioned',
#   'several',
#   'second',
#   'baseman',
#   'second',
#   'shortstop',
#   'second',
#   'baseman',
#   'outfield',
#   'position',
#   'fielder',
#   'center',
#   'fielder',
#   'fielder',
#   'exception',
#   'catcher',
#   'fielder',
#   'required',
#   'territory',
#   'delivered',
#   'neutral',
#   'umpire',
#   'behind',
#   'catcher',
#   'umpire',
#   'distributed',
#   'around',
#   'member',
#   'batting',
#   'batter',
#   'standing',
#   'either',
#   'batter',
#   'holding',
#   'batter',
#   'pitcher',
#   'toward',
#   'attempt',
#   'catcher',
#   'batter',
#   'result',
#   'either',
#   'electing',
#   'failing',
#   'connect',
#   'return',
#   'pitcher',
#   'batter',
#   'running',
#   'toward',
#   'player',
#   'referred',
#   'runner',
#   'batter',
#   'runner',
#   'batter',
#   'runner',
#   'without',
#   'batter',
#   'runner',
#   'choose',
#   'remain',
#   'attempt',
#   'advance',
#   'second',
#   'beyond',
#   'however',
#   'player',
#   'belief',
#   'reached',
#   'safely',
#   'player',
#   'despite',
#   'proper',
#   'fielder',
#   'recorded',
#   'player',
#   'safely',
#   'credited',
#   'single',
#   'player',
#   'second',
#   'safely',
#   'direct',
#   'result',
#   'double',
#   'triple',
#   'within',
#   'entire',
#   'outfield',
#   'outfield',
#   'otherwise',
#   'safely',
#   'circle',
#   'batter',
#   'runner',
#   'freely',
#   'circle',
#   'scoring',
#   'desirable',
#   'result',
#   'batter',
#   'player',
#   'fielding',
#   'mistake',
#   'credited',
#   'instead',
#   'responsible',
#   'fielder',
#   'charged',
#   'runner',
#   'already',
#   'attempt',
#   'advance',
#   'batted',
#   'contact',
#   'ground',
#   'territory',
#   'runner',
#   'attempt',
#   'advance',
#   'runner',
#   'occupy',
#   'passing',
#   'infield',
#   'becomes',
#   'runner',
#   'return',
#   'occupied',
#   'caught',
#   'batter',
#   'runner',
#   'attempt',
#   'advance',
#   'contact',
#   'occupied',
#   'caught',
#   'runner',
#   'attempt',
#   'advance',
#   'pitcher',
#   'process',
#   'delivering',
#   'successful',
#   'effort',
#   'stolen',
#   'called',
#   'either',
#   'strike',
#   'batter',
#   'strike',
#   'recorded',
#   'strike',
#   'batter',
#   'recorded',
#   'awarded',
#   'advance',
#   'batter',
#   'freely',
#   'advance',
#   'batter',
#   'uniform',
#   'struck',
#   'outside',
#   'strike',
#   'provided',
#   'batter',
#   'attempt',
#   'crucial',
#   'determining',
#   'strike',
#   'umpire',
#   'judgment',
#   'whether',
#   'passed',
#   'strike',
#   'conceptual',
#   'extending',
#   'midpoint',
#   'batter',
#   'shoulder',
#   'hollow',
#   'trying',
#   'attempting',
#   'record',
#   'addition',
#   'strikeout',
#   'flyout',
#   'common',
#   'member',
#   'batting',
#   'include',
#   'ground',
#   'either',
#   'runner',
#   'forced',
#   'advance',
#   'fielder',
#   'possession',
#   'runner',
#   'runner',
#   'touched',
#   'fielder',
#   'possible',
#   'record',
#   'course',
#   'called',
#   'double',
#   'triple',
#   'possible',
#   'though',
#   'player',
#   'retired',
#   'returning',
#   'dugout',
#   'runner',
#   'stranded',
#   'recorded',
#   'another',
#   'player',
#   'stranded',
#   'runner',
#   'benefit',
#   'inning',
#   'individual',
#   'player',
#   'batting',
#   'appearance',
#   'complete',
#   'player',
#   'result',
#   'recorded',
#   'teammate',
#   'occasion',
#   'batter',
#   'without',
#   'batter',
#   'hitting',
#   'recorded',
#   'teammate',
#   'instance',
#   'runner',
#   'getting',
#   'caught',
#   'stealing',
#   'tagged',
#   'attempting',
#   'batter',
#   'incomplete',
#   'appearance',
#   'batting',
#   'strike',
#   'recorded',
#   'batter',
#   'previous',
#   'inning',
#   'erased',
#   'runner',
#   'circle',
#   'appearance',
#   'single',
#   'batting',
#   'player',
#   'completed',
#   'appearance',
#   'player',
#   'member',
#   'player',
#   'batting',
#   'batting',
#   'altered',
#   'except',
#   'substitution',
#   'player',
#   'removed',
#   'substitute',
#   'player',
#   'reenter',
#   'lenient',
#   'little',
#   'league',
#   'player',
#   'substituted',
#   'designated',
#   'hitter',
#   'effect',
#   'player',
#   'responsibility',
#   'another',
#   'player',
#   'almost',
#   'invariably',
#   'pitcher',
#   'batting',
#   'batting',
#   'player',
#   'fielding',
#   'arrangement',
#   'player',
#   'personnel',
#   'player',
#   'number',
#   'player',
#   'baseball',
#   'roster',
#   'varies',
#   'league',
#   'organized',
#   'league',
#   'baseball',
#   'roster',
#   'player',
#   'specific',
#   'typical',
#   'roster',
#   'feature',
#   'following',
#   'player',
#   'position',
#   'player',
#   'catcher',
#   'infielder',
#   'outfielder',
#   'regular',
#   'starting',
#   'pitcher',
#   'constitute',
#   'pitching',
#   'rotation',
#   'starting',
#   'rotation',
#   'relief',
#   'pitcher',
#   'including',
#   'closer',
#   'constitute',
#   'bullpen',
#   'pitcher',
#   'backup',
#   'substitute',
#   'catcher',
#   'backup',
#   'infielder',
#   'backup',
#   'outfielder',
#   'hitter',
#   'utility',
#   'player',
#   'seventh',
#   'relievermost',
#   'baseball',
#   'league',
#   'worldwide',
#   'including',
#   'american',
#   'league',
#   'pacific',
#   'league',
#   'caribbean',
#   'professional',
#   'league',
#   'american',
#   'amateur',
#   'organization',
#   'central',
#   'league',
#   'national',
#   'league',
#   'league',
#   'connected',
#   'national',
#   'league',
#   'required',
#   'league',
#   'designated',
#   'hitter',
#   'typical',
#   'offensive',
#   'regular',
#   'including',
#   'starting',
#   'pitcher',
#   'reliever',
#   'backup',
#   'catcher',
#   'reserve',
#   'player',
#   'manager',
#   'manager',
#   'oversees',
#   'strategic',
#   'decision',
#   'establishing',
#   'starting',
#   'rotation',
#   'setting',
#   'lineup',
#   'batting',
#   'making',
#   'substitution',
#   'particular',
#   'bringing',
#   'relief',
#   'pitcher',
#   'manager',
#   'typically',
#   'assisted',
#   'specialized',
#   'responsibility',
#   'working',
#   'player',
#   'hitting',
#   'fielding',
#   'pitching',
#   'strength',
#   'conditioning',
#   'organized',
#   'stationed',
#   'occupy',
#   'designated',
#   'outside',
#   'assist',
#   'direction',
#   'baserunners',
#   'tactical',
#   'signal',
#   'manager',
#   'batter',
#   'runner',
#   'contrast',
#   'baseball',
#   'manager',
#   'generally',
#   'uniform',
#   'uniform',
#   'allowed',
#   'confer',
#   'player',
#   'umpire',
#   'baseball',
#   'involves',
#   'umpire',
#   'ruling',
#   'outcome',
#   'minimum',
#   'umpire',
#   'behind',
#   'catcher',
#   'strike',
#   'strike',
#   'additional',
#   'umpire',
#   'stationed',
#   'making',
#   'easier',
#   'attempted',
#   'umpire',
#   'playoff',
#   'umpire',
#   'outfield',
#   'strategy',
#   'strategic',
#   'decision',
#   'baseball',
#   'revolve',
#   'around',
#   'fundamental',
#   'general',
#   'handed',
#   'batter',
#   'successful',
#   'handed',
#   'pitcher',
#   'greater',
#   'degree',
#   'handed',
#   'batter',
#   'successful',
#   'handed',
#   'pitcher',
#   'manager',
#   'several',
#   'handed',
#   'batter',
#   'regular',
#   'lineup',
#   'facing',
#   'handed',
#   'starting',
#   'pitcher',
#   'respond',
#   'starting',
#   'handed',
#   'backup',
#   'roster',
#   'inning',
#   'relief',
#   'pitcher',
#   'hitter',
#   'brought',
#   'opposing',
#   'manager',
#   'trying',
#   'create',
#   'favorable',
#   'matchup',
#   'substitution',
#   'manager',
#   'fielding',
#   'trying',
#   'arrange',
#   'handed',
#   'pitcher',
#   'batter',
#   'matchup',
#   'manager',
#   'batting',
#   'trying',
#   'arrange',
#   'opposite',
#   'handed',
#   'matchup',
#   'inning',
#   'manager',
#   'remove',
#   'starting',
#   'position',
#   'player',
#   'especially',
#   'likely',
#   'skillful',
#   'fielder',
#   'defensive',
#   'substitution',
#   'tactic',
#   'pitching',
#   'fielding',
#   'tactical',
#   'decision',
#   'precedes',
#   'almost',
#   'baseball',
#   'involves',
#   'selection',
#   'gripping',
#   'releasing',
#   'baseball',
#   'certain',
#   'manner',
#   'throwing',
#   'certain',
#   'pitcher',
#   'baseball',
#   'either',
#   'downward',
#   'approach',
#   'batter',
#   'creating',
#   'differing',
#   'selected',
#   'resulting',
#   'variety',
#   'thrown',
#   'fastball',
#   'changeup',
#   'breaking',
#   'curveball',
#   'slider',
#   'pitcher',
#   'different',
#   'repertoire',
#   'skillful',
#   'throwing',
#   'conventionally',
#   'catcher',
#   'signal',
#   'pitcher',
#   'general',
#   'vertical',
#   'horizontal',
#   'location',
#   'disagreement',
#   'selection',
#   'pitcher',
#   'catcher',
#   'different',
#   'runner',
#   'taking',
#   'pitcher',
#   'attempt',
#   'pickoff',
#   'fielder',
#   'covering',
#   'runner',
#   'optimally',
#   'effect',
#   'pickoff',
#   'attempt',
#   'however',
#   'subject',
#   'severely',
#   'restrict',
#   'pitcher',
#   'movement',
#   'pickoff',
#   'attempt',
#   'violation',
#   'result',
#   'umpire',
#   'calling',
#   'pitcher',
#   'permit',
#   'runner',
#   'advance',
#   'impunity',
#   'attempted',
#   'stolen',
#   'anticipated',
#   'catcher',
#   'pitchout',
#   'thrown',
#   'deliberately',
#   'allowing',
#   'catcher',
#   'standing',
#   'quickly',
#   'facing',
#   'batter',
#   'strong',
#   'tendency',
#   'fielding',
#   'employ',
#   'fielder',
#   'moving',
#   'position',
#   'runner',
#   'infielder',
#   'moving',
#   'closer',
#   'improve',
#   'throwing',
#   'runner',
#   'ground',
#   'though',
#   'sharply',
#   'grounder',
#   'likely',
#   'infield',
#   'batting',
#   'baserunning',
#   ...],
#  ['politics',
#   'πολιτικά',
#   'politiká',
#   'affair',
#   'method',
#   'rulership',
#   'national',
#   'government',
#   'government',
#   'government',
#   'ruling',
#   'relation',
#   'individual',
#   'distribution',
#   'resource',
#   'status',
#   'branch',
#   'social',
#   'science',
#   'rulership',
#   'making',
#   'government',
#   'referred',
#   'political',
#   'science',
#   'positively',
#   'context',
#   'political',
#   'solution',
#   'compromising',
#   'nonviolent',
#   'descriptively',
#   'science',
#   'government',
#   'negative',
#   'connotation',
#   'example',
#   'abolitionist',
#   'wendell',
#   'phillips',
#   'declared',
#   'politics',
#   'slavery',
#   'concept',
#   'defined',
#   'various',
#   'different',
#   'approach',
#   'fundamentally',
#   'differing',
#   'whether',
#   'extensively',
#   'limitedly',
#   'empirically',
#   'normatively',
#   'whether',
#   'conflict',
#   'operation',
#   'essential',
#   'variety',
#   'method',
#   'deployed',
#   'politics',
#   'include',
#   'promoting',
#   'political',
#   'people',
#   'negotiation',
#   'political',
#   'subject',
#   'making',
#   'exercising',
#   'including',
#   'warfare',
#   'adversary',
#   'politics',
#   'exercised',
#   'social',
#   'traditional',
#   'society',
#   'modern',
#   'government',
#   'company',
#   'institution',
#   'sovereign',
#   'international',
#   'modern',
#   'nation',
#   'people',
#   'political',
#   'represent',
#   'member',
#   'position',
#   'support',
#   'change',
#   'leader',
#   'election',
#   'usually',
#   'competition',
#   'different',
#   'political',
#   'system',
#   'framework',
#   'defines',
#   'acceptable',
#   'political',
#   'method',
#   'within',
#   'society',
#   'history',
#   'political',
#   'thought',
#   'traced',
#   'antiquity',
#   'seminal',
#   'republic',
#   'aristotle',
#   'politics',
#   'confucius',
#   'political',
#   'manuscript',
#   'chanakya',
#   'arthashastra',
#   'etymology',
#   'english',
#   'politics',
#   'aristotle',
#   'classic',
#   'politiká',
#   'introduced',
#   'politiká',
#   'πολιτικά',
#   'affair',
#   'century',
#   'aristotle',
#   'composition',
#   'rendered',
#   'modern',
#   'english',
#   'polettiques',
#   'become',
#   'politics',
#   'modern',
#   'english',
#   'singular',
#   'politic',
#   'attested',
#   'english',
#   'coming',
#   'middle',
#   'french',
#   'politique',
#   'taking',
#   'politicus',
#   'latinization',
#   'πολιτικός',
#   'politikos',
#   'πολίτης',
#   'polites',
#   'citizen',
#   'definition',
#   'harold',
#   'lasswell',
#   'politics',
#   'easton',
#   'authoritative',
#   'allocation',
#   'society',
#   'vladimir',
#   'politics',
#   'concentrated',
#   'expression',
#   'economics',
#   'bernard',
#   'argued',
#   'politics',
#   'distinctive',
#   'whereby',
#   'people',
#   'together',
#   'institutionalized',
#   'procedure',
#   'resolve',
#   'difference',
#   'conciliate',
#   'diverse',
#   'interest',
#   'public',
#   'policy',
#   'pursuit',
#   'common',
#   'purpose',
#   'according',
#   'adrian',
#   'leftwich',
#   'politics',
#   'comprises',
#   'activity',
#   'operation',
#   'negotiation',
#   'conflict',
#   'within',
#   'society',
#   'whereby',
#   'people',
#   'organizing',
#   'production',
#   'distribution',
#   'natural',
#   'resource',
#   'course',
#   'production',
#   'reproduction',
#   'biological',
#   'social',
#   'politics',
#   'sphere',
#   'activity',
#   'involved',
#   'running',
#   'according',
#   'webber',
#   'defined',
#   'community',
#   'successfully',
#   'monopoly',
#   'legitimate',
#   'physical',
#   'within',
#   'territory',
#   'manjunath',
#   'politics',
#   'people',
#   'approach',
#   'several',
#   'approaching',
#   'politics',
#   'conceptualized',
#   'extensive',
#   'limited',
#   'adrian',
#   'leftwich',
#   'differentiated',
#   'politics',
#   'extensive',
#   'limited',
#   'perception',
#   'account',
#   'political',
#   'extensive',
#   'politics',
#   'present',
#   'across',
#   'sphere',
#   'social',
#   'relation',
#   'limited',
#   'restricts',
#   'certain',
#   'context',
#   'example',
#   'restrictive',
#   'politics',
#   'viewed',
#   'primarily',
#   'governance',
#   'feminist',
#   'perspective',
#   'viewed',
#   'traditionally',
#   'political',
#   'indeed',
#   'viewed',
#   'political',
#   'latter',
#   'position',
#   'encapsulated',
#   'slogan',
#   'personal',
#   'political',
#   'dispute',
#   'distinction',
#   'private',
#   'public',
#   'instead',
#   'politics',
#   'defined',
#   'argued',
#   'robert',
#   'moralism',
#   'realism',
#   'perspective',
#   'politics',
#   'empirically',
#   'exercise',
#   'others',
#   'social',
#   'function',
#   'normative',
#   'distinction',
#   'called',
#   'difference',
#   'political',
#   'moralism',
#   'political',
#   'realism',
#   'moralist',
#   'politics',
#   'closely',
#   'linked',
#   'extreme',
#   'utopian',
#   'thinking',
#   'example',
#   'according',
#   'hannah',
#   'arendt',
#   'aristotle',
#   'political',
#   'everything',
#   'decided',
#   'persuasion',
#   'violence',
#   'according',
#   'bernard',
#   'olitics',
#   'society',
#   'governed',
#   'politics',
#   'politics',
#   'something',
#   'contrast',
#   'realist',
#   'represented',
#   'niccolò',
#   'machiavelli',
#   'thomas',
#   'hobbes',
#   'harold',
#   'lasswell',
#   'politics',
#   'irrespective',
#   'pursued',
#   'conflict',
#   'operation',
#   'agonism',
#   'argues',
#   'politics',
#   'essentially',
#   'conflict',
#   'conflicting',
#   'interest',
#   'political',
#   'scientist',
#   'schattschneider',
#   'argued',
#   'politics',
#   'universal',
#   'language',
#   'conflict',
#   'schmitt',
#   'essence',
#   'politics',
#   'distinction',
#   'friend',
#   'direct',
#   'contrast',
#   'operative',
#   'politics',
#   'aristotle',
#   'however',
#   'extreme',
#   'provided',
#   'political',
#   'scientist',
#   'michael',
#   'politics',
#   'characteristic',
#   'conflict',
#   'operation',
#   'interaction',
#   'conflict',
#   'operation',
#   'politics',
#   'mixture',
#   'history',
#   'history',
#   'politics',
#   'history',
#   'limited',
#   'modern',
#   'institution',
#   'government',
#   'prehistoric',
#   'argued',
#   'already',
#   'chimpanzee',
#   'engage',
#   'politics',
#   'social',
#   'manipulation',
#   'secure',
#   'maintain',
#   'influential',
#   'position',
#   'social',
#   'organization',
#   'lacked',
#   'centralized',
#   'political',
#   'structure',
#   'sometimes',
#   'referred',
#   'stateless',
#   'society',
#   'ancient',
#   'history',
#   'civilization',
#   'definite',
#   'boundary',
#   'border',
#   'accurately',
#   'described',
#   'frontier',
#   'dynastic',
#   'dynastic',
#   'civilization',
#   'define',
#   'border',
#   'moreover',
#   'century',
#   'people',
#   'society',
#   'relatively',
#   'egalitarian',
#   'complex',
#   'highly',
#   'stratified',
#   'chiefdoms',
#   'formation',
#   'number',
#   'different',
#   'theory',
#   'hypothesis',
#   'regarding',
#   'formation',
#   'generalization',
#   'explain',
#   'developed',
#   'others',
#   'scholar',
#   'believe',
#   'generalization',
#   'unhelpful',
#   'formation',
#   'treated',
#   'voluntary',
#   'theory',
#   'contend',
#   'diverse',
#   'people',
#   'together',
#   'result',
#   'shared',
#   'rational',
#   'interest',
#   'theory',
#   'largely',
#   'development',
#   'agriculture',
#   'population',
#   'organizational',
#   'pressure',
#   'followed',
#   'resulted',
#   'formation',
#   'prominent',
#   'theory',
#   'primary',
#   'formation',
#   'hydraulic',
#   'hypothesis',
#   'contends',
#   'result',
#   'maintain',
#   'irrigation',
#   'project',
#   'conflict',
#   'theory',
#   'formation',
#   'regard',
#   'conflict',
#   'dominance',
#   'population',
#   'another',
#   'population',
#   'formation',
#   'contrast',
#   'voluntary',
#   'theory',
#   'argument',
#   'believe',
#   'people',
#   'voluntarily',
#   'create',
#   'maximize',
#   'benefit',
#   'oppression',
#   'others',
#   'theory',
#   'warfare',
#   'critical',
#   'formation',
#   'ancient',
#   'history',
#   'dynastic',
#   'dynastic',
#   'period',
#   'predynastic',
#   'respectively',
#   'around',
#   'approximately',
#   'dynastic',
#   'around',
#   'africa',
#   'kingdom',
#   'boundary',
#   'around',
#   'stretching',
#   'existed',
#   'dynastic',
#   'located',
#   'southern',
#   'mesopotamia',
#   'border',
#   'extending',
#   'persian',
#   'euphrates',
#   'tigris',
#   'although',
#   'existed',
#   'ancient',
#   'empire',
#   'people',
#   'explicitly',
#   'formulated',
#   'political',
#   'philosophy',
#   'rationally',
#   'analyzed',
#   'political',
#   'institution',
#   'described',
#   'justified',
#   'religious',
#   'several',
#   'important',
#   'political',
#   'innovation',
#   'classical',
#   'antiquity',
#   'republic',
#   'century',
#   'granted',
#   'citizenship',
#   'population',
#   'athens',
#   'combined',
#   'directly',
#   'democratic',
#   'government',
#   'afterlife',
#   'political',
#   'thought',
#   'history',
#   'modern',
#   'westphalia',
#   'considered',
#   'political',
#   'scientist',
#   'beginning',
#   'modern',
#   'international',
#   'system',
#   'external',
#   'interfering',
#   'another',
#   'country',
#   'domestic',
#   'affair',
#   'principle',
#   'interference',
#   'country',
#   'domestic',
#   'affair',
#   'century',
#   'jurist',
#   'vattel',
#   'became',
#   'primary',
#   'institutional',
#   'interstate',
#   'system',
#   'relation',
#   'westphalia',
#   'attempt',
#   'impose',
#   'supranational',
#   'authority',
#   'european',
#   'westphalian',
#   'doctrine',
#   'independent',
#   'bolstered',
#   'century',
#   'thought',
#   'nationalism',
#   'legitimate',
#   'assumed',
#   'correspond',
#   'nation',
#   'people',
#   'united',
#   'language',
#   'culture',
#   'europe',
#   'century',
#   'classic',
#   'national',
#   'multinational',
#   'empire',
#   'austrian',
#   'empire',
#   'kingdom',
#   'france',
#   'kingdom',
#   'hungary',
#   'russian',
#   'empire',
#   'spanish',
#   'empire',
#   'ottoman',
#   'empire',
#   'british',
#   'empire',
#   'empire',
#   'existed',
#   'africa',
#   'america',
#   'muslim',
#   'immediately',
#   'muhammad',
#   'caliphate',
#   'established',
#   'developed',
#   'ethnic',
#   'national',
#   'empire',
#   'multinational',
#   'empire',
#   'absolute',
#   'monarchy',
#   'emperor',
#   'sultan',
#   'population',
#   'belonged',
#   'ethnic',
#   'language',
#   'empire',
#   'dominated',
#   'ethnic',
#   'language',
#   'usually',
#   'language',
#   'public',
#   'administration',
#   'ruling',
#   'dynasty',
#   'usually',
#   'always',
#   'smaller',
#   'european',
#   'ethnically',
#   'diverse',
#   'dynastic',
#   'smaller',
#   'survived',
#   'independent',
#   'principality',
#   'liechtenstein',
#   'andorra',
#   'monaco',
#   'republic',
#   'marino',
#   'theory',
#   'nation',
#   'century',
#   'european',
#   'phenomenon',
#   'facilitated',
#   'development',
#   'mandated',
#   'education',
#   'literacy',
#   'medium',
#   'however',
#   'historian',
#   'emergence',
#   'relatively',
#   'unified',
#   'identity',
#   'portugal',
#   'republic',
#   'scholar',
#   'steven',
#   'woodward',
#   'michel',
#   'foucault',
#   'jeremy',
#   'advanced',
#   'hypothesis',
#   'nation',
#   'political',
#   'ingenuity',
#   'unknown',
#   'undetermined',
#   'source',
#   'accident',
#   'history',
#   'political',
#   'invention',
#   'rather',
#   'nation',
#   'inadvertent',
#   'byproduct',
#   'century',
#   'intellectual',
#   'discovery',
#   'political',
#   'economy',
#   'capitalism',
#   'mercantilism',
#   'political',
#   'geography',
#   'geography',
#   'combined',
#   'cartography',
#   'advance',
#   'making',
#   'technology',
#   'nation',
#   'germany',
#   'existence',
#   'partly',
#   'result',
#   'political',
#   'campaign',
#   'nationalist',
#   'century',
#   'territory',
#   'previously',
#   'divided',
#   'liberal',
#   'played',
#   'german',
#   'unification',
#   'preceded',
#   'custom',
#   'zollverein',
#   'national',
#   'determination',
#   'aspect',
#   'united',
#   'president',
#   'woodrow',
#   'wilson',
#   'fourteen',
#   'leading',
#   'dissolution',
#   'austro',
#   'hungarian',
#   'empire',
#   'ottoman',
#   'empire',
#   'russian',
#   'empire',
#   'became',
#   'soviet',
#   'russian',
#   'decolonization',
#   'creation',
#   'nation',
#   'multinational',
#   'empire',
#   'globalization',
#   'political',
#   'globalization',
#   'century',
#   'intergovernmental',
#   'organization',
#   'supranational',
#   'league',
#   'nation',
#   'founded',
#   'replaced',
#   'united',
#   'nation',
#   'various',
#   'international',
#   'treaty',
#   'signed',
#   'regional',
#   'integration',
#   'pursued',
#   'african',
#   'european',
#   'mercosur',
#   'international',
#   'political',
#   'institution',
#   'international',
#   'include',
#   'international',
#   'criminal',
#   'international',
#   'monetary',
#   'organization',
#   'political',
#   'science',
#   'politics',
#   'called',
#   'political',
#   'science',
#   'politology',
#   'comprises',
#   'numerous',
#   'subfields',
#   'including',
#   'comparative',
#   'politics',
#   'political',
#   'economy',
#   'international',
#   'relation',
#   'political',
#   'philosophy',
#   'public',
#   'administration',
#   'public',
#   'policy',
#   'gender',
#   'politics',
#   'political',
#   'methodology',
#   'furthermore',
#   'political',
#   'science',
#   'related',
#   'economics',
#   'sociology',
#   'history',
#   'philosophy',
#   'geography',
#   'psychology',
#   'psychiatry',
#   'anthropology',
#   'neuroscience',
#   'comparative',
#   'politics',
#   'science',
#   'comparison',
#   'teaching',
#   'different',
#   'constitution',
#   'political',
#   'legislature',
#   'associated',
#   'intrastate',
#   'perspective',
#   'international',
#   'relation',
#   'interaction',
#   'nation',
#   'intergovernmental',
#   'transnational',
#   'organization',
#   'political',
#   'philosophy',
#   'concerned',
#   'contribution',
#   'various',
#   'classical',
#   'contemporary',
#   'thinker',
#   'philosopher',
#   'political',
#   'science',
#   'methodologically',
#   'diverse',
#   'appropriates',
#   'method',
#   'originating',
#   'psychology',
#   'social',
#   'research',
#   'cognitive',
#   'neuroscience',
#   'approach',
#   'include',
#   'positivism',
#   'interpretivism',
#   'rational',
#   'choice',
#   'theory',
#   'behavioralism',
#   'structuralism',
#   'structuralism',
#   'realism',
#   'institutionalism',
#   'pluralism',
#   'political',
#   'science',
#   'social',
#   'science',
#   'method',
#   'technique',
#   'relate',
#   'inquiry',
#   'sought',
#   'primary',
#   'source',
#   'historical',
#   'document',
#   'official',
#   'record',
#   'secondary',
#   'source',
#   'scholarly',
#   'journal',
#   'article',
#   'survey',
#   'research',
#   'statistical',
#   'analysis',
#   'experimental',
#   'research',
#   'building',
#   'political',
#   'system',
#   'political',
#   'system',
#   'defines',
#   'process',
#   'making',
#   'official',
#   'government',
#   'decision',
#   'usually',
#   'compared',
#   'system',
#   'economic',
#   'system',
#   'cultural',
#   'system',
#   'social',
#   'system',
#   'according',
#   'easton',
#   'political',
#   'system',
#   'designated',
#   'interaction',
#   'authoritatively',
#   'allocated',
#   'society',
#   'political',
#   'system',
#   'embedded',
#   'society',
#   'political',
#   'culture',
#   'society',
#   'public',
#   'policy',
#   'interaction',
#   'different',
#   'political',
#   'system',
#   'global',
#   'politics',
#   'government',
#   'government',
#   'classified',
#   'several',
#   'structure',
#   'monarchy',
#   'including',
#   'constitutional',
#   'monarchy',
#   'republic',
#   ...],
#  ['astronomy',
#   'ἀστρονομία',
#   'literally',
#   'meaning',
#   'science',
#   'natural',
#   'science',
#   'celestial',
#   'object',
#   'phenomenon',
#   'mathematics',
#   'physic',
#   'chemistry',
#   'explain',
#   'origin',
#   'evolution',
#   'object',
#   'interest',
#   'include',
#   'planet',
#   'nebula',
#   'galaxy',
#   'relevant',
#   'phenomenon',
#   'include',
#   'supernova',
#   'explosion',
#   'quasar',
#   'blazars',
#   'pulsar',
#   'cosmic',
#   'microwave',
#   'background',
#   'radiation',
#   'generally',
#   'astronomy',
#   'everything',
#   'originates',
#   'beyond',
#   'atmosphere',
#   'cosmology',
#   'branch',
#   'astronomy',
#   'universe',
#   'astronomy',
#   'oldest',
#   'natural',
#   'science',
#   'civilization',
#   'recorded',
#   'history',
#   'methodical',
#   'observation',
#   'include',
#   'babylonian',
#   'indian',
#   'egyptian',
#   'chinese',
#   'ancient',
#   'indigenous',
#   'people',
#   'america',
#   'astronomy',
#   'included',
#   'discipline',
#   'diverse',
#   'astrometry',
#   'celestial',
#   'navigation',
#   'observational',
#   'astronomy',
#   'making',
#   'calendar',
#   'nowadays',
#   'professional',
#   'astronomy',
#   'astrophysics',
#   'professional',
#   'astronomy',
#   'observational',
#   'theoretical',
#   'branch',
#   'observational',
#   'astronomy',
#   'focused',
#   'acquiring',
#   'observation',
#   'astronomical',
#   'object',
#   'analyzed',
#   'principle',
#   'physic',
#   'theoretical',
#   'astronomy',
#   'oriented',
#   'toward',
#   'development',
#   'computer',
#   'analytical',
#   'describe',
#   'astronomical',
#   'object',
#   'phenomenon',
#   'complement',
#   'theoretical',
#   'astronomy',
#   'explain',
#   'observational',
#   'result',
#   'observation',
#   'confirm',
#   'theoretical',
#   'result',
#   'astronomy',
#   'science',
#   'amateur',
#   'active',
#   'especially',
#   'discovery',
#   'observation',
#   'transient',
#   'amateur',
#   'astronomer',
#   'helped',
#   'important',
#   'discovery',
#   'finding',
#   'etymology',
#   'astronomy',
#   'ἀστρονομία',
#   'ἄστρον',
#   'astron',
#   'culture',
#   'culture',
#   'depending',
#   'translation',
#   'astronomy',
#   'confused',
#   'astrology',
#   'belief',
#   'system',
#   'affair',
#   'correlated',
#   'position',
#   'celestial',
#   'object',
#   'although',
#   'common',
#   'origin',
#   'entirely',
#   'distinct',
#   'astronomy',
#   'astrophysics',
#   'astronomy',
#   'astrophysics',
#   'synonym',
#   'strict',
#   'dictionary',
#   'definition',
#   'astronomy',
#   'refers',
#   'object',
#   'matter',
#   'outside',
#   'atmosphere',
#   'physical',
#   'chemical',
#   'property',
#   'astrophysics',
#   'refers',
#   'branch',
#   'astronomy',
#   'dealing',
#   'behavior',
#   'physical',
#   'property',
#   'dynamic',
#   'process',
#   'celestial',
#   'object',
#   'phenomenon',
#   'introduction',
#   'introductory',
#   'textbook',
#   'physical',
#   'universe',
#   'astronomy',
#   'describe',
#   'qualitative',
#   'subject',
#   'whereas',
#   'astrophysics',
#   'describe',
#   'physic',
#   'oriented',
#   'version',
#   'subject',
#   'however',
#   'modern',
#   'astronomical',
#   'research',
#   'subject',
#   'related',
#   'physic',
#   'modern',
#   'astronomy',
#   'actually',
#   'called',
#   'astrophysics',
#   'astrometry',
#   'purely',
#   'astronomy',
#   'rather',
#   'astrophysics',
#   'various',
#   'department',
#   'scientist',
#   'research',
#   'subject',
#   'astronomy',
#   'astrophysics',
#   'partly',
#   'depending',
#   'whether',
#   'department',
#   'historically',
#   'affiliated',
#   'physic',
#   'department',
#   'professional',
#   'astronomer',
#   'physic',
#   'rather',
#   'astronomy',
#   'degree',
#   'leading',
#   'scientific',
#   'journal',
#   'include',
#   'astronomical',
#   'journal',
#   'astrophysical',
#   'journal',
#   'astronomy',
#   'astrophysics',
#   'history',
#   'ancient',
#   'historic',
#   'astronomy',
#   'consisted',
#   'observation',
#   'prediction',
#   'motion',
#   'object',
#   'visible',
#   'location',
#   'culture',
#   'assembled',
#   'massive',
#   'artifact',
#   'possibly',
#   'astronomical',
#   'purpose',
#   'addition',
#   'ceremonial',
#   'observatory',
#   'employed',
#   'determine',
#   'season',
#   'important',
#   'factor',
#   'knowing',
#   'understanding',
#   'length',
#   'telescope',
#   'invented',
#   'conducted',
#   'civilization',
#   'developed',
#   'notably',
#   'mesopotamia',
#   'greece',
#   'persia',
#   'central',
#   'america',
#   'astronomical',
#   'observatory',
#   'assembled',
#   'nature',
#   'universe',
#   'develop',
#   'astronomy',
#   'consisted',
#   'mapping',
#   'position',
#   'planet',
#   'science',
#   'referred',
#   'astrometry',
#   'observation',
#   'motion',
#   'planet',
#   'formed',
#   'nature',
#   'universe',
#   'explored',
#   'philosophically',
#   'believed',
#   'center',
#   'universe',
#   'rotating',
#   'around',
#   'geocentric',
#   'universe',
#   'ptolemaic',
#   'system',
#   'ptolemy',
#   'particularly',
#   'important',
#   'development',
#   'beginning',
#   'mathematical',
#   'scientific',
#   'astronomy',
#   'babylonian',
#   'foundation',
#   'astronomical',
#   'tradition',
#   'developed',
#   'civilization',
#   'babylonian',
#   'discovered',
#   'eclipse',
#   'recurred',
#   'repeating',
#   'following',
#   'babylonian',
#   'significant',
#   'advance',
#   'astronomy',
#   'ancient',
#   'greece',
#   'hellenistic',
#   'astronomy',
#   'characterized',
#   'seeking',
#   'rational',
#   'physical',
#   'explanation',
#   'celestial',
#   'phenomenon',
#   'century',
#   'aristarchus',
#   'estimated',
#   'distance',
#   'proposed',
#   'system',
#   'planet',
#   'rotated',
#   'around',
#   'called',
#   'heliocentric',
#   'century',
#   'hipparchus',
#   'discovered',
#   'precession',
#   'calculated',
#   'distance',
#   'invented',
#   'earliest',
#   'astronomical',
#   'device',
#   'astrolabe',
#   'hipparchus',
#   'created',
#   'comprehensive',
#   'catalog',
#   'constellation',
#   'northern',
#   'hemisphere',
#   'derive',
#   'astronomy',
#   'antikythera',
#   'mechanism',
#   'analog',
#   'computer',
#   'designed',
#   'calculate',
#   'location',
#   'planet',
#   'technological',
#   'artifact',
#   'similar',
#   'complexity',
#   'reappear',
#   'century',
#   'mechanical',
#   'astronomical',
#   'appeared',
#   'europe',
#   'middle',
#   'medieval',
#   'europe',
#   'housed',
#   'number',
#   'important',
#   'astronomer',
#   'richard',
#   'wallingford',
#   'contribution',
#   'astronomy',
#   'horology',
#   'including',
#   'invention',
#   'astronomical',
#   'rectangulus',
#   'allowed',
#   'measurement',
#   'planet',
#   'astronomical',
#   'equatorium',
#   'called',
#   'albion',
#   'astronomical',
#   'calculation',
#   'planetary',
#   'longitude',
#   'predict',
#   'eclipse',
#   'nicole',
#   'oresme',
#   'buridan',
#   'discussed',
#   'evidence',
#   'rotation',
#   'furthermore',
#   'buridan',
#   'developed',
#   'theory',
#   'impetus',
#   'predecessor',
#   'modern',
#   'scientific',
#   'theory',
#   'inertia',
#   'planet',
#   'capable',
#   'motion',
#   'without',
#   'intervention',
#   'peuerbach',
#   'regiomontanus',
#   'helped',
#   'astronomical',
#   'progress',
#   'instrumental',
#   'copernicus',
#   'development',
#   'heliocentric',
#   'decade',
#   'astronomy',
#   'flourished',
#   'islamic',
#   'emergence',
#   'astronomical',
#   'observatory',
#   'muslim',
#   'century',
#   'andromeda',
#   'galaxy',
#   'largest',
#   'galaxy',
#   'described',
#   'persian',
#   'muslim',
#   'astronomer',
#   'rahman',
#   'supernova',
#   'brightest',
#   'apparent',
#   'magnitude',
#   'stellar',
#   'recorded',
#   'history',
#   'observed',
#   'egyptian',
#   'arabic',
#   'astronomer',
#   'ridwan',
#   'chinese',
#   'astronomer',
#   'prominent',
#   'islamic',
#   'mostly',
#   'persian',
#   'astronomer',
#   'significant',
#   'contribution',
#   'science',
#   'include',
#   'battani',
#   'thebit',
#   'rahman',
#   'biruni',
#   'ibrāhīm',
#   'zarqālī',
#   'birjandi',
#   'astronomer',
#   'maragheh',
#   'samarkand',
#   'observatory',
#   'astronomer',
#   'introduced',
#   'arabic',
#   'individual',
#   'believed',
#   'zimbabwe',
#   'timbuktu',
#   'housed',
#   'astronomical',
#   'observatory',
#   'classical',
#   'africa',
#   'astronomer',
#   'studied',
#   'movement',
#   'relation',
#   'season',
#   'crafting',
#   'heaven',
#   'precise',
#   'diagram',
#   'planet',
#   'complex',
#   'mathematical',
#   'calculation',
#   'songhai',
#   'historian',
#   'mahmud',
#   'documented',
#   'meteor',
#   'shower',
#   'august',
#   'european',
#   'previously',
#   'believed',
#   'astronomical',
#   'observation',
#   'saharan',
#   'africa',
#   'colonial',
#   'middle',
#   'modern',
#   'discovery',
#   'otherwise',
#   'century',
#   'recovery',
#   'ancient',
#   'learning',
#   'middle',
#   'enlightenment',
#   'catholic',
#   'church',
#   'financial',
#   'social',
#   'support',
#   'astronomy',
#   'probably',
#   'institution',
#   'church',
#   'finding',
#   'easter',
#   'scientific',
#   'revolution',
#   'renaissance',
#   'nicolaus',
#   'copernicus',
#   'proposed',
#   'heliocentric',
#   'system',
#   'defended',
#   'galileo',
#   'galilei',
#   'expanded',
#   'johannes',
#   'kepler',
#   'kepler',
#   'devise',
#   'system',
#   'correctly',
#   'described',
#   'detail',
#   'motion',
#   'planet',
#   'around',
#   'however',
#   'kepler',
#   'succeed',
#   'formulating',
#   'theory',
#   'behind',
#   'newton',
#   'invention',
#   'celestial',
#   'dynamic',
#   'gravitation',
#   'finally',
#   'explained',
#   'motion',
#   'planet',
#   'newton',
#   'developed',
#   'reflecting',
#   'telescope',
#   'improvement',
#   'quality',
#   'telescope',
#   'discovery',
#   'english',
#   'astronomer',
#   'flamsteed',
#   'catalogued',
#   'extensive',
#   'catalogue',
#   'produced',
#   'nicolas',
#   'lacaille',
#   'astronomer',
#   'william',
#   'herschel',
#   'detailed',
#   'catalog',
#   'nebulosity',
#   'cluster',
#   'discovered',
#   'planet',
#   'uranus',
#   'planet',
#   'century',
#   'problem',
#   'leonhard',
#   'alexis',
#   'claude',
#   'clairaut',
#   'alembert',
#   'accurate',
#   'prediction',
#   'motion',
#   'planet',
#   'refined',
#   'joseph',
#   'lagrange',
#   'pierre',
#   'laplace',
#   'allowing',
#   'planet',
#   'estimated',
#   'perturbation',
#   'significant',
#   'advance',
#   'astronomy',
#   'introduction',
#   'technology',
#   'including',
#   'spectroscope',
#   'photography',
#   'joseph',
#   'fraunhofer',
#   'discovered',
#   'spectrum',
#   'gustav',
#   'kirchhoff',
#   'ascribed',
#   'presence',
#   'different',
#   'element',
#   'proven',
#   'similar',
#   'temperature',
#   'existence',
#   'galaxy',
#   'proved',
#   'century',
#   'existence',
#   'external',
#   'galaxy',
#   'observed',
#   'recession',
#   'galaxy',
#   'discovery',
#   'expansion',
#   'universe',
#   'theoretical',
#   'astronomy',
#   'speculation',
#   'existence',
#   'object',
#   'neutron',
#   'explain',
#   'observed',
#   'phenomenon',
#   'quasar',
#   'pulsar',
#   'blazars',
#   'galaxy',
#   'physical',
#   'cosmology',
#   'advance',
#   'century',
#   'theory',
#   'formulated',
#   'heavily',
#   'evidenced',
#   'cosmic',
#   'microwave',
#   'background',
#   'radiation',
#   'hubble',
#   'cosmological',
#   'abundance',
#   'element',
#   'telescope',
#   'enabled',
#   'measurement',
#   'electromagnetic',
#   'spectrum',
#   'normally',
#   'blocked',
#   'blurred',
#   'atmosphere',
#   'february',
#   'revealed',
#   'project',
#   'detected',
#   'evidence',
#   'gravitational',
#   'previous',
#   'september',
#   'observational',
#   'astronomy',
#   'source',
#   'information',
#   'celestial',
#   'object',
#   'visible',
#   'generally',
#   'electromagnetic',
#   'radiation',
#   'observational',
#   'astronomy',
#   'categorized',
#   'according',
#   'corresponding',
#   'region',
#   'electromagnetic',
#   'spectrum',
#   'observation',
#   'spectrum',
#   'observed',
#   'surface',
#   'observable',
#   'either',
#   'altitude',
#   'outside',
#   'atmosphere',
#   'specific',
#   'information',
#   'subfields',
#   'astronomy',
#   'astronomy',
#   'radiation',
#   'wavelength',
#   'greater',
#   'approximately',
#   'millimeter',
#   'outside',
#   'visible',
#   'astronomy',
#   'different',
#   'observational',
#   'astronomy',
#   'observed',
#   'treated',
#   'rather',
#   'discrete',
#   'photon',
#   'relatively',
#   'easier',
#   'measure',
#   'amplitude',
#   'whereas',
#   'easily',
#   'shorter',
#   'wavelength',
#   'although',
#   'emitted',
#   'directly',
#   'astronomical',
#   'object',
#   'product',
#   'thermal',
#   'emission',
#   'emission',
#   'observed',
#   'result',
#   'synchrotron',
#   'radiation',
#   'produced',
#   'electron',
#   'magnetic',
#   'additionally',
#   'number',
#   'spectral',
#   'produced',
#   'interstellar',
#   'notably',
#   'hydrogen',
#   'spectral',
#   'observable',
#   'wavelength',
#   'variety',
#   'object',
#   'observable',
#   'wavelength',
#   'including',
#   'supernova',
#   'interstellar',
#   'pulsar',
#   'active',
#   'galactic',
#   'nucleus',
#   'infrared',
#   'astronomy',
#   'infrared',
#   'astronomy',
#   'founded',
#   'detection',
#   'analysis',
#   'infrared',
#   'radiation',
#   'wavelength',
#   'longer',
#   'outside',
#   'vision',
#   'infrared',
#   'spectrum',
#   'useful',
#   'studying',
#   'object',
#   'radiate',
#   'visible',
#   'planet',
#   'circumstellar',
#   'nebula',
#   'blocked',
#   'longer',
#   'wavelength',
#   'infrared',
#   'penetrate',
#   'visible',
#   'allowing',
#   'observation',
#   'embedded',
#   'molecular',
#   'galaxy',
#   'observation',
#   'infrared',
#   'survey',
#   'explorer',
#   'particularly',
#   'effective',
#   'unveiling',
#   'numerous',
#   'galactic',
#   'protostars',
#   'cluster',
#   'exception',
#   'infrared',
#   'wavelength',
#   'visible',
#   'radiation',
#   'heavily',
#   'absorbed',
#   'atmosphere',
#   'masked',
#   'atmosphere',
#   'produce',
#   'significant',
#   'infrared',
#   'emission',
#   'consequently',
#   'infrared',
#   'observatory',
#   'located',
#   'molecule',
#   'radiate',
#   'strongly',
#   'infrared',
#   'allows',
#   'chemistry',
#   'specifically',
#   'detect',
#   'optical',
#   'astronomy',
#   'historically',
#   'optical',
#   'astronomy',
#   'called',
#   'visible',
#   'astronomy',
#   'oldest',
#   'astronomy',
#   'observation',
#   'originally',
#   'century',
#   'century',
#   'photographic',
#   'equipment',
#   'modern',
#   'digital',
#   'detector',
#   'particularly',
#   'charge',
#   'coupled',
#   'device',
#   'recorded',
#   'modern',
#   'medium',
#   'although',
#   'visible',
#   'extends',
#   'approximately',
#   'equipment',
#   'observe',
#   'ultraviolet',
#   'infrared',
#   'radiation',
#   'ultraviolet',
#   'astronomy',
#   'ultraviolet',
#   'astronomy',
#   'employ',
#   'ultraviolet',
#   'wavelength',
#   'approximately',
#   'wavelength',
#   'absorbed',
#   'atmosphere',
#   'requiring',
#   'observation',
#   'wavelength',
#   'performed',
#   'atmosphere',
#   'ultraviolet',
#   'astronomy',
#   'suited',
#   'thermal',
#   'radiation',
#   'spectral',
#   'emission',
#   'bright',
#   'includes',
#   'galaxy',
#   'target',
#   'several',
#   'ultraviolet',
#   'survey',
#   'object',
#   'commonly',
#   'observed',
#   'ultraviolet',
#   'include',
#   'planetary',
#   'nebula',
#   'supernova',
#   'remnant',
#   'active',
#   'galactic',
#   'nucleus',
#   'however',
#   'ultraviolet',
#   'easily',
#   'absorbed',
#   'interstellar',
#   'adjustment',
#   'ultraviolet',
#   'measurement',
#   'necessary',
#   'astronomy',
#   'astronomy',
#   'wavelength',
#   'typically',
#   'radiation',
#   'produced',
#   'synchrotron',
#   'emission',
#   'result',
#   'electron',
#   'orbiting',
#   'magnetic',
#   ...],
#  ['cricket',
#   'played',
#   'eleven',
#   'player',
#   'centre',
#   'wicket',
#   'comprising',
#   'balanced',
#   'proceeds',
#   'player',
#   'fielding',
#   'called',
#   'bowler',
#   'propels',
#   'towards',
#   'wicket',
#   'completed',
#   'legally',
#   'batting',
#   'player',
#   'player',
#   'opposite',
#   'bowler',
#   'aiming',
#   'strike',
#   'batting',
#   'either',
#   'boundary',
#   'batter',
#   'result',
#   'fielding',
#   'prevent',
#   'scoring',
#   'dismiss',
#   'batter',
#   'wicket',
#   'dismissal',
#   'include',
#   'bowled',
#   'bowled',
#   'dislodges',
#   'fielding',
#   'either',
#   'catching',
#   'ground',
#   'hitting',
#   'wicket',
#   'batter',
#   'crease',
#   'wicket',
#   'complete',
#   'batter',
#   'dismissed',
#   'inning',
#   'adjudicated',
#   'umpire',
#   'umpire',
#   'referee',
#   'international',
#   'cricket',
#   'twenty20',
#   'batting',
#   'single',
#   'inning',
#   'generally',
#   'lasting',
#   'played',
#   'traditionally',
#   'cricketer',
#   'limited',
#   'cricket',
#   'colour',
#   'addition',
#   'player',
#   'protective',
#   'prevent',
#   'injury',
#   'caused',
#   'spheroid',
#   'compressed',
#   'leather',
#   'slightly',
#   'raised',
#   'enclosing',
#   'layered',
#   'tightly',
#   'string',
#   'earliest',
#   'reference',
#   'cricket',
#   'england',
#   'century',
#   'spread',
#   'globally',
#   'expansion',
#   'british',
#   'empire',
#   'international',
#   'second',
#   'century',
#   'governing',
#   'international',
#   'cricket',
#   'council',
#   'member',
#   'twelve',
#   'member',
#   'cricket',
#   'maintained',
#   'marylebone',
#   'cricket',
#   'london',
#   'followed',
#   'primarily',
#   'australasia',
#   'united',
#   'kingdom',
#   'southern',
#   'africa',
#   'cricket',
#   'organised',
#   'played',
#   'separately',
#   'achieved',
#   'international',
#   'standard',
#   'successful',
#   'playing',
#   'international',
#   'cricket',
#   'australia',
#   'international',
#   'trophy',
#   'including',
#   'country',
#   'country',
#   'history',
#   'origin',
#   'cricket',
#   'sphere',
#   'basically',
#   'involve',
#   'hitting',
#   'implement',
#   'others',
#   'include',
#   'baseball',
#   'similarity',
#   'cricket',
#   'belonging',
#   'specific',
#   'category',
#   'hockey',
#   'tennis',
#   'squash',
#   'badminton',
#   'tennis',
#   'cricket',
#   'difference',
#   'existence',
#   'target',
#   'structure',
#   'wicket',
#   'originally',
#   'thought',
#   'wicket',
#   'herded',
#   'batter',
#   'defend',
#   'cricket',
#   'historian',
#   'altham',
#   'identified',
#   'hockey',
#   'driven',
#   'target',
#   'driven',
#   'towards',
#   'undefended',
#   'target',
#   'cricket',
#   'wicket',
#   'driven',
#   'generally',
#   'believed',
#   'cricket',
#   'originated',
#   'eastern',
#   'county',
#   'england',
#   'sometime',
#   'medieval',
#   'period',
#   'although',
#   'earliest',
#   'definite',
#   'reference',
#   'cricket',
#   'played',
#   'evidence',
#   'guildford',
#   'january',
#   'equating',
#   'january',
#   'modern',
#   'calendar',
#   'concerned',
#   'ownership',
#   'certain',
#   'testimony',
#   'coroner',
#   'derrick',
#   'witness',
#   'scholler',
#   'schoole',
#   'guldeford',
#   'diverse',
#   'fellow',
#   'creckett',
#   'derrick',
#   'century',
#   'earlier',
#   'school',
#   'certain',
#   'cricket',
#   'played',
#   'surrey',
#   'originally',
#   'reinforced',
#   'randle',
#   'cotgrave',
#   'english',
#   'french',
#   'dictionary',
#   'defined',
#   'crosse',
#   'crooked',
#   'wherewith',
#   'cricket',
#   'crosser',
#   'cricket',
#   'possible',
#   'source',
#   'english',
#   'meaning',
#   'crutch',
#   'samuel',
#   'johnson',
#   'dictionary',
#   'derived',
#   'cricket',
#   'french',
#   'criquet',
#   'strong',
#   'medieval',
#   'connection',
#   'england',
#   'county',
#   'flanders',
#   'latter',
#   'belonged',
#   'burgundy',
#   'derived',
#   'middle',
#   'flanders',
#   'meaning',
#   'another',
#   'possible',
#   'source',
#   'middle',
#   'krickstoel',
#   'meaning',
#   'kneeling',
#   'church',
#   'resembled',
#   'wicket',
#   'cricket',
#   'according',
#   'heiner',
#   'gillmeister',
#   'european',
#   'language',
#   'expert',
#   'university',
#   'cricket',
#   'derives',
#   'middle',
#   'phrase',
#   'hockey',
#   'gillmeister',
#   'suggested',
#   'flemish',
#   'origin',
#   'growth',
#   'amateur',
#   'professional',
#   'cricket',
#   'england',
#   'although',
#   'object',
#   'always',
#   'cricket',
#   'differed',
#   'modern',
#   'certain',
#   'technical',
#   'aspect',
#   'american',
#   'variant',
#   'cricket',
#   'wicket',
#   'retained',
#   'aspect',
#   'bowled',
#   'underarm',
#   'bowler',
#   'ground',
#   'towards',
#   'batter',
#   'resembled',
#   'hockey',
#   'batter',
#   'defended',
#   'wicket',
#   'called',
#   'scorer',
#   'recorded',
#   'notching',
#   'cotgrave',
#   'dictionary',
#   'published',
#   'ecclesiastical',
#   'record',
#   'sidlesham',
#   'sussex',
#   'parishioner',
#   'bartholomew',
#   'richard',
#   'latter',
#   'failed',
#   'attend',
#   'church',
#   'easter',
#   'sunday',
#   'playing',
#   'cricket',
#   'ordered',
#   'penance',
#   'earliest',
#   'mention',
#   'participation',
#   'cricket',
#   'around',
#   'earliest',
#   'organised',
#   'parish',
#   'village',
#   'played',
#   'chevening',
#   'player',
#   'called',
#   'jasper',
#   'vinall',
#   'accidentally',
#   'struck',
#   'parish',
#   'sussex',
#   'cricket',
#   'remained',
#   'pursuit',
#   'century',
#   'numerous',
#   'reference',
#   'record',
#   'ecclesiastical',
#   'proscribed',
#   'puritan',
#   'commonwealth',
#   'problem',
#   'nearly',
#   'always',
#   'sunday',
#   'puritan',
#   'considered',
#   'cricket',
#   'profane',
#   'played',
#   'sabbath',
#   'especially',
#   'gambling',
#   'involved',
#   'according',
#   'social',
#   'historian',
#   'birley',
#   'upsurge',
#   'restoration',
#   'several',
#   'member',
#   'charles',
#   'strong',
#   'interest',
#   'cricket',
#   'gambling',
#   'became',
#   'problem',
#   'significant',
#   'enough',
#   'parliament',
#   'gambling',
#   'limiting',
#   'colossal',
#   'exceeding',
#   'annual',
#   'income',
#   'population',
#   'prizefighting',
#   'racing',
#   'cricket',
#   'perceived',
#   'gambling',
#   'patron',
#   'forming',
#   'engaged',
#   'professional',
#   'player',
#   'century',
#   'cricket',
#   'developed',
#   'spreading',
#   'throughout',
#   'england',
#   'already',
#   'abroad',
#   'english',
#   'mariner',
#   'coloniser',
#   'earliest',
#   'reference',
#   'cricket',
#   'overseas',
#   'newspaper',
#   'report',
#   'survives',
#   'cricket',
# ...
#   'titled',
#   'address',
#   'director',
#   'ingmar',
#   'bergman',
#   'famously',
#   'andrei',
#   'tarkovsky',
#   'greatest',
#   'director',
#   'invented',
#   'language',
#   'nature',
#   'capture',
#   'reflection',
#   'example',
#   'language',
#   'sequence',
#   'speaking',
#   'profile',
#   'followed',
#   'another',
#   'speaking',
#   'profile',
#   'repetition',
#   'language',
#   'understood',
#   'audience',
#   'indicate',
#   'conversation',
#   'describes',
#   'another',
#   'theory',
#   'degree',
#   'visual',
#   'telling',
#   'device',
#   'ability',
#   'viewer',
#   'context',
#   'psychologically',
#   'present',
#   'visual',
#   'composition',
#   'editing',
#   'hollywood',
#   'includes',
#   'narrative',
#   'theory',
#   'overwhelming',
#   'practice',
#   'studio',
#   'hollywood',
#   'california',
#   'classical',
#   'another',
#   'example',
#   'cinematic',
#   'language',
#   'forehead',
#   'expression',
#   'silent',
#   'reflection',
#   'younger',
#   'vaguely',
#   'resembles',
#   'indicating',
#   'person',
#   'remembering',
#   'composition',
#   'transition',
#   'montage',
#   'montage',
#   'technique',
#   'separate',
#   'selected',
#   'edited',
#   'pieced',
#   'together',
#   'section',
#   'battle',
#   'flashback',
#   'special',
#   'effect',
#   'placed',
#   'filming',
#   'complete',
#   'filmed',
#   'separately',
#   'perhaps',
#   'different',
#   'version',
#   'called',
#   'montage',
#   'director',
#   'developed',
#   'theory',
#   'montage',
#   'beginning',
#   'eisenstein',
#   'complex',
#   'juxtaposition',
#   'battleship',
#   'potemkin',
#   'incorporation',
#   'musical',
#   'visual',
#   'counterpoint',
#   'development',
#   'editing',
#   'effect',
#   'complex',
#   'technique',
#   'comparable',
#   'ballet',
#   'criticism',
#   'criticism',
#   'analysis',
#   'evaluation',
#   'general',
#   'divided',
#   'category',
#   'academic',
#   'criticism',
#   'scholar',
#   'journalistic',
#   'criticism',
#   'appears',
#   'regularly',
#   'newspaper',
#   'medium',
#   'critic',
#   'working',
#   'newspaper',
#   'magazine',
#   'broadcast',
#   'medium',
#   'mainly',
#   'review',
#   'release',
#   'normally',
#   'formulate',
#   'opinion',
#   'despite',
#   'critic',
#   'important',
#   'impact',
#   'audience',
#   'response',
#   'attendance',
#   'especially',
#   ...],
#  ['verifiable',
#   'record',
#   'generally',
#   'accepted',
#   'payment',
#   'service',
#   'repayment',
#   'particular',
#   'country',
#   'economic',
#   'context',
#   'function',
#   'distinguished',
#   'medium',
#   'exchange',
#   'account',
#   'sometimes',
#   'standard',
#   'deferred',
#   'payment',
#   'verifiable',
#   'record',
#   'fulfils',
#   'function',
#   'considered',
#   'historically',
#   'emergent',
#   'market',
#   'phenomenon',
#   'establishing',
#   'commodity',
#   'nearly',
#   'contemporary',
#   'system',
#   'without',
#   'physical',
#   'commodity',
#   'derives',
#   'declared',
#   'government',
#   'tender',
#   'accepted',
#   'payment',
#   'within',
#   'boundary',
#   'country',
#   'public',
#   'private',
#   'counterfeit',
#   'supply',
#   'country',
#   'consists',
#   'currency',
#   'banknote',
#   'depending',
#   'particular',
#   'definition',
#   'balance',
#   'checking',
#   'account',
#   'saving',
#   'account',
#   'account',
#   'consists',
#   'record',
#   'mostly',
#   'computerized',
#   'modern',
#   'banking',
#   'largest',
#   'developed',
#   'country',
#   'etymology',
#   'derives',
#   'moneta',
#   'meaning',
#   'french',
#   'monnaie',
#   'believed',
#   'originate',
#   'temple',
#   'capitoline',
#   'ancient',
#   'associated',
#   'temple',
#   'moneta',
#   'ancient',
#   'located',
#   'derived',
#   'etruscan',
#   'goddess',
#   'unique',
#   'united',
#   'moneta',
#   'either',
#   'monere',
#   'remind',
#   'instruct',
#   'moneres',
#   'unique',
#   'western',
#   'prevalent',
#   'specie',
#   'stemming',
#   'specie',
#   'meaning',
#   'history',
#   'barter',
#   'method',
#   'though',
#   'evidence',
#   'society',
#   'economy',
#   'relied',
#   'primarily',
#   'barter',
#   'instead',
#   'monetary',
#   'society',
#   'operated',
#   'largely',
#   'principle',
#   'economy',
#   'barter',
#   'usually',
#   'either',
#   'complete',
#   'stranger',
#   'potential',
#   'culture',
#   'around',
#   'eventually',
#   'developed',
#   'commodity',
#   'mesopotamian',
#   'shekel',
#   'weight',
#   'relied',
#   'something',
#   'barley',
#   'mesopotamia',
#   'society',
#   'america',
#   'africa',
#   'australia',
#   'cypraea',
#   'moneta',
#   'annulus',
#   'according',
#   'herodotus',
#   'lydian',
#   'people',
#   'introduce',
#   'silver',
#   'thought',
#   'modern',
#   'scholar',
#   'stamped',
#   'minted',
#   'around',
#   'system',
#   'commodity',
#   'eventually',
#   'evolved',
#   'system',
#   'representative',
#   'occurred',
#   'silver',
#   'merchant',
#   'receipt',
#   'depositor',
#   'redeemable',
#   'commodity',
#   'deposited',
#   'eventually',
#   'receipt',
#   'became',
#   'generally',
#   'accepted',
#   'payment',
#   'banknote',
#   'dynasty',
#   'banknote',
#   'jiaozi',
#   'evolved',
#   'promissory',
#   'century',
#   'however',
#   'displace',
#   'commodity',
#   'alongside',
#   'century',
#   'became',
#   'europe',
#   'account',
#   'traveller',
#   'william',
#   'rubruck',
#   'account',
#   'dynasty',
#   'subject',
#   'chapter',
#   'travel',
#   'titled',
#   'causeth',
#   'something',
#   'country',
#   'banknote',
#   'issued',
#   'europe',
#   'stockholm',
#   'alongside',
#   'standard',
#   'monetary',
#   'system',
#   'medium',
#   'exchange',
#   'convertible',
#   'quantity',
#   'replaced',
#   'currency',
#   'century',
#   'europe',
#   'standard',
#   'tender',
#   'redemption',
#   'discouraged',
#   'beginning',
#   'century',
#   'almost',
#   'country',
#   'adopted',
#   'standard',
#   'backing',
#   'tender',
#   'amount',
#   'bretton',
#   'conference',
#   'country',
#   'adopted',
#   'currency',
#   'dollar',
#   'dollar',
#   'government',
#   'suspended',
#   'convertibility',
#   'dollar',
#   'country',
#   'pegged',
#   'currency',
#   'dollar',
#   'currency',
#   'became',
#   'unbacked',
#   'anything',
#   'except',
#   'government',
#   'tender',
#   'ability',
#   'convert',
#   'payment',
#   'according',
#   'proponent',
#   'modern',
#   'theory',
#   'backed',
#   'imposing',
#   'create',
#   'demand',
#   'currency',
#   'function',
#   'mechanism',
#   'exchange',
#   'william',
#   'stanley',
#   'jevons',
#   'famously',
#   'analyzed',
#   'function',
#   'medium',
#   'exchange',
#   'common',
#   'measure',
#   'account',
#   'standard',
#   'standard',
#   'deferred',
#   'payment',
#   'jevons',
#   'function',
#   'summarized',
#   'couplet',
#   'matter',
#   'function',
#   'medium',
#   'measure',
#   'standard',
#   'couplet',
#   'become',
#   'widely',
#   'popular',
#   'macroeconomics',
#   'textbook',
#   'modern',
#   'textbook',
#   'function',
#   'medium',
#   'exchange',
#   'account',
#   'considering',
#   'standard',
#   'deferred',
#   'payment',
#   'distinguished',
#   'function',
#   'rather',
#   'subsuming',
#   'others',
#   'historical',
#   'dispute',
#   'regarding',
#   'combination',
#   'function',
#   'arguing',
#   'separation',
#   'single',
#   'insufficient',
#   'argument',
#   'medium',
#   'exchange',
#   'conflict',
#   'requires',
#   'holding',
#   'without',
#   'spending',
#   'whereas',
#   'medium',
#   'exchange',
#   'requires',
#   'circulate',
#   'others',
#   'storing',
#   'deferral',
#   'exchange',
#   'diminish',
#   'medium',
#   'exchange',
#   'transported',
#   'across',
#   'financial',
#   'capital',
#   'general',
#   'inclusive',
#   'liquid',
#   'instrument',
#   'whether',
#   'uniformly',
#   'recognized',
#   'tender',
#   'medium',
#   'exchange',
#   'intermediate',
#   'exchange',
#   'service',
#   'performing',
#   'function',
#   'medium',
#   'exchange',
#   'thereby',
#   'avoids',
#   'inefficiency',
#   'barter',
#   'system',
#   'inability',
#   'permanently',
#   'ensure',
#   'coincidence',
#   'example',
#   'barter',
#   'system',
#   'indicating',
#   'existence',
#   'coincidence',
#   'medium',
#   'exchange',
#   'alleviate',
#   'former',
#   'freedom',
#   'instead',
#   'burdened',
#   'latter',
#   'meanwhile',
#   'latter',
#   'medium',
#   'exchange',
#   'provide',
#   'measure',
#   'account',
#   'economics',
#   'standard',
#   'numerical',
#   'monetary',
#   'measurement',
#   'market',
#   'service',
#   'transaction',
#   'measure',
#   'standard',
#   'relative',
#   'deferred',
#   'payment',
#   'account',
#   'necessary',
#   'prerequisite',
#   'formulation',
#   'commercial',
#   'agreement',
#   'involve',
#   'standard',
#   'measure',
#   'common',
#   'denomination',
#   'quoting',
#   'bargaining',
#   'necessary',
#   'developing',
#   'efficient',
#   'accounting',
#   'system',
#   'standard',
#   'deferred',
#   'payment',
#   'standard',
#   'deferred',
#   'payment',
#   'distinguished',
#   'particularly',
#   'subsume',
#   'function',
#   'standard',
#   'deferred',
#   'payment',
#   'accepted',
#   'settle',
#   'denominated',
#   'status',
#   'tender',
#   'jurisdiction',
#   'concept',
#   'function',
#   'discharge',
#   'denominated',
#   'change',
#   'inflation',
#   'deflation',
#   'sovereign',
#   'international',
#   'debasement',
#   'devaluation',
#   'reliably',
#   'stored',
#   'retrieved',
#   'predictably',
#   'usable',
#   'medium',
#   'exchange',
#   'retrieved',
#   'remain',
#   'stable',
#   'argued',
#   'inflation',
#   'reducing',
#   'diminishes',
#   'ability',
#   'function',
#   'property',
#   'according',
#   'desjardins',
#   'economist',
#   'expert',
#   'property',
#   'medium',
#   'exchange',
#   'account',
#   'fulfill',
#   'various',
#   'function',
#   'fungible',
#   'individual',
#   'capable',
#   'mutual',
#   'substitution',
#   'interchangeability',
#   'durable',
#   'withstand',
#   'repeated',
#   'divisibile',
#   'divisible',
#   'portable',
#   'easily',
#   'carried',
#   'transported',
#   'acceptable',
#   'everyone',
#   'accept',
#   'payment',
#   'uniform',
#   'denomination',
#   'limited',
#   'supply',
#   'supply',
#   'circulation',
#   'limited',
#   'supply',
#   'economics',
#   'financial',
#   'instrument',
#   'fulfill',
#   'function',
#   'detailed',
#   'financial',
#   'instrument',
#   'together',
#   'collectively',
#   'referred',
#   'supply',
#   'economy',
#   'supply',
#   'number',
#   'financial',
#   'instrument',
#   'within',
#   'specific',
#   'economy',
#   'available',
#   'purchasing',
#   'service',
#   'supply',
#   'consists',
#   'various',
#   'financial',
#   'instrument',
#   'usually',
#   'currency',
#   'demand',
#   'deposit',
#   'various',
#   'deposit',
#   'amount',
#   'economy',
#   'measured',
#   'adding',
#   'together',
#   'financial',
#   'instrument',
#   'creating',
#   'monetary',
#   'aggregate',
#   'modern',
#   'monetary',
#   'theory',
#   'distinguishes',
#   'different',
#   'measure',
#   'supply',
#   'reflected',
#   'different',
#   'monetary',
#   'aggregate',
#   'categorization',
#   'system',
#   'liquidity',
#   'financial',
#   'instrument',
#   'commonly',
#   'monetary',
#   'aggregate',
#   'conventionally',
#   'designated',
#   'successively',
#   'larger',
#   'aggregate',
#   'category',
#   'currency',
#   'demand',
#   'deposit',
#   'checking',
#   'account',
#   'saving',
#   'account',
#   'deposit',
#   'larger',
#   'deposit',
#   'similar',
#   'institutional',
#   'account',
#   'includes',
#   'liquid',
#   'financial',
#   'instrument',
#   'relatively',
#   'illiquid',
#   'instrument',
#   'precise',
#   'definition',
#   'different',
#   'different',
#   'country',
#   'another',
#   'measure',
#   'unlike',
#   'measure',
#   'represent',
#   'actual',
#   'purchasing',
#   'household',
#   'economy',
#   'amount',
#   'actually',
#   'issued',
#   'central',
#   'country',
#   'measured',
#   'currency',
#   'deposit',
#   'institution',
#   'central',
#   'satisfy',
#   'reserve',
#   'requirement',
#   'commercial',
#   'creation',
#   'current',
#   'economic',
#   'system',
#   'created',
#   'procedure',
#   'tender',
#   'narrow',
#   'created',
#   'central',
#   'minting',
#   'printing',
#   'banknote',
#   'created',
#   'private',
#   'recording',
#   'deposit',
#   'borrowing',
#   'client',
#   'partial',
#   'support',
#   'indicated',
#   'currently',
#   'created',
#   'electronic',
#   'country',
#   'majority',
#   'mostly',
#   'created',
#   'commercial',
#   'making',
#   'contrary',
#   'popular',
#   'misconception',
#   'simply',
#   'intermediary',
#   'lending',
#   'deposit',
#   'depend',
#   'central',
#   'create',
#   'deposit',
#   'market',
#   'liquidity',
#   'market',
#   'liquidity',
#   'describes',
#   'easily',
#   'traded',
#   'another',
#   'common',
#   'currency',
#   'within',
#   'economy',
#   'liquid',
#   'universally',
#   'recognized',
#   'accepted',
#   'common',
#   'currency',
#   'consumer',
#   'freedom',
#   'service',
#   'easily',
#   'without',
#   'barter',
#   'liquid',
#   'financial',
#   'instrument',
#   'easily',
#   'tradable',
#   'transaction',
#   'minimal',
#   'spread',
#   'instrument',
#   'commodity',
#   'commodity',
#   'naturally',
#   'scarce',
#   'precious',
#   'barley',
#   'thought',
#   'commodity',
#   'commodity',
#   'commodity',
#   'constitutes',
#   'commodity',
#   'example',
#   'commodity',
#   'medium',
#   'exchange',
#   'include',
#   'silver',
#   'copper',
#   'wampum',
#   'peppercorn',
#   'decorated',
#   'alcohol',
#   'cigarette',
#   'cannabis',
#   'sometimes',
#   'metric',
#   'perceived',
#   'conjunction',
#   'another',
#   'various',
#   'commodity',
#   'valuation',
#   'system',
#   'economy',
#   'commodity',
#   'similar',
#   'barter',
#   'commodity',
#   'provides',
#   'simple',
#   'automatic',
#   'account',
#   'commodity',
#   'although',
#   'krugerrand',
#   'considered',
#   'tender',
#   'record',
#   'either',
#   'rationale',
#   'emphasis',
#   'direct',
#   'prevailing',
#   'content',
#   'american',
#   'imprinted',
#   'content',
#   'tender',
#   'representative',
#   'british',
#   'economist',
#   'william',
#   'stanley',
#   'jevons',
#   'described',
#   'representative',
#   'representative',
#   'consists',
#   'physical',
#   'certificate',
#   'reliably',
#   'exchanged',
#   'quantity',
#   'commodity',
#   'silver',
#   'representative',
#   'direct',
#   'relation',
#   'commodity',
#   'composed',
#   'commodity',
#   'currency',
#   'derived',
#   'intrinsic',
#   'guarantee',
#   'converted',
#   'valuable',
#   'commodity',
#   'instead',
#   'government',
#   'usually',
#   'government',
#   'declares',
#   'currency',
#   'typically',
#   'central',
#   'federal',
#   'reserve',
#   'system',
#   'tender',
#   'making',
#   'unlawful',
#   'accept',
#   'currency',
#   'repayment',
#   'public',
#   'private',
#   'bullion',
#   'australian',
#   'nugget',
#   'american',
#   'tender',
#   'however',
#   'market',
#   'content',
#   'commodity',
#   'rather',
#   'tender',
#   'usually',
#   'fraction',
#   'bullion',
#   'physically',
#   'represented',
#   'currency',
#   'accidentally',
#   'damaged',
#   'destroyed',
#   'however',
#   'advantage',
#   'representative',
#   'commodity',
#   'created',
#   'define',
#   'replacement',
#   'damage',
#   'destruction',
#   'example',
#   'government',
#   'replace',
#   'mutilated',
#   'federal',
#   'reserve',
#   'physical',
#   'reconstructed',
#   'otherwise',
#   'proven',
#   'destroyed',
#   'contrast',
#   'commodity',
#   'destroyed',
#   'cannot',
#   'recovered',
#   'coinage',
#   'factor',
#   'silver',
#   'silver',
#   'bronze',
#   'copper',
#   'precious',
#   'weighed',
#   'stamped',
#   'assure',
#   'individual',
#   'taking',
#   'getting',
#   'certain',
#   'weight',
#   'precious',
#   'counterfeited',
#   'created',
#   'account',
#   'helped',
#   'banking',
#   'archimedes',
#   'principle',
#   'provided',
#   'easily',
#   'tested',
#   'weight',
#   'determined',
#   'shaved',
#   'debased',
#   'otherwise',
#   'tampered',
#   'numismatics',
#   'economy',
#   'coinage',
#   'copper',
#   'silver',
#   'formed',
#   'purchase',
#   'payment',
#   'military',
#   'backing',
#   'activity',
#   'silver',
#   'midsized',
#   'transaction',
#   'account',
#   'contract',
#   'fealty',
#   'copper',
#   'represented',
#   'coinage',
#   'common',
#   'transaction',
#   'system',
#   'ancient',
#   'mahajanapadas',
#   'europe',
#   'system',
#   'worked',
#   'medieval',
#   'period',
#   'virtually',
#   'silver',
#   'copper',
#   'introduced',
#   'mining',
#   'conquest',
#   'overall',
#   'coinage',
#   'remained',
#   'roughly',
#   'equivalent',
#   'premodern',
#   'credit',
#   'circulating',
#   'medium',
#   'burden',
#   'exchanging',
#   'thousand',
#   'copper',
#   'introduction',
#   'commonly',
#   'banknote',
#   'economic',
#   'phenomenon',
#   'gradual',
#   'process',
#   'dynasty',
#   'dynasty',
#   'merchant',
#   'exchange',
#   'coinage',
#   'receipt',
#   'deposit',
#   'issued',
#   'promissory',
#   'wholesaler',
#   'temporary',
#   'regional',
#   'territory',
#   'century',
#   'dynasty',
#   'government',
#   'circulating',
#   'amongst',
#   'trader',
#   'monopolized',
#   'industry',
#   'government',
#   'granted',
#   'several',
#   'banknote',
#   'century',
#   'government',
#   'finally',
#   'produce',
#   'issued',
#   'currency',
#   'banknote',
#   'issued',
#   'regionally',
#   'temporary',
#   'century',
#   'standard',
#   'uniform',
#   'government',
#   'acceptable',
#   'nationwide',
#   'currency',
#   'already',
#   'widespread',
#   'method',
#   'woodblock',
#   'printing',
#   'movable',
#   'printing',
#   'century',
#   'impetus',
#   'massive',
#   'production',
#   ...]]

# %%
from gensim import corpora

# %%
input_dict = corpora.Dictionary(processed_data)
input_corpus = [input_dict.doc2bow(token, allow_update = True) for token in processed_data]
input_corpus[0:10]
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 5),
#   (3, 1),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 2),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 2),
#   (14, 1),
#   (15, 3),
#   (16, 1),
#   (17, 2),
#   (18, 1),
#   (19, 2),
#   (20, 1),
#   (21, 1),
#   (22, 3),
#   (23, 1),
#   (24, 15),
#   (25, 2),
#   (26, 1),
#   (27, 2),
#   (28, 1),
#   (29, 4),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 2),
#   (39, 4),
#   (40, 3),
#   (41, 1),
#   (42, 3),
#   (43, 1),
#   (44, 2),
#   (45, 2),
#   (46, 1),
#   (47, 4),
#   (48, 7),
#   (49, 30),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 4),
#   (54, 1),
#   (55, 5),
#   (56, 1),
#   (57, 1),
#   (58, 1),
#   (59, 6),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 14),
#   (65, 3),
#   (66, 1),
#   (67, 3),
#   (68, 1),
#   (69, 1),
#   (70, 4),
#   (71, 1),
#   (72, 4),
#   (73, 1),
#   (74, 1),
#   (75, 1),
#   (76, 1),
#   (77, 16),
#   (78, 2),
#   (79, 3),
#   (80, 12),
#   (81, 1),
#   (82, 4),
#   (83, 1),
#   (84, 1),
#   (85, 1),
#   (86, 1),
#   (87, 2),
#   (88, 2),
#   (89, 1),
#   (90, 12),
#   (91, 1),
#   (92, 1),
#   (93, 5),
#   (94, 1),
#   (95, 1),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 163),
#   (101, 1),
#   (102, 4),
#   (103, 1),
#   (104, 2),
#   (105, 4),
#   (106, 1),
#   (107, 1),
#   (108, 3),
#   (109, 67),
#   (110, 34),
#   (111, 1),
#   (112, 1),
#   (113, 7),
#   (114, 2),
#   (115, 2),
#   (116, 1),
#   (117, 3),
#   (118, 1),
#   (119, 3),
#   (120, 1),
#   (121, 3),
#   (122, 1),
#   (123, 1),
#   (124, 1),
#   (125, 3),
#   (126, 3),
#   (127, 1),
#   (128, 1),
#   (129, 2),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 4),
#   (135, 1),
#   (136, 1),
#   (137, 1),
#   (138, 2),
#   (139, 4),
#   (140, 1),
#   (141, 3),
#   (142, 2),
#   (143, 1),
#   (144, 2),
#   (145, 4),
#   (146, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 4),
#   (151, 8),
#   (152, 1),
#   (153, 7),
#   (154, 1),
#   (155, 1),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 1),
#   (160, 5),
#   (161, 1),
#   (162, 1),
#   (163, 12),
#   (164, 1),
#   (165, 1),
#   (166, 5),
#   (167, 1),
#   (168, 4),
#   (169, 1),
#   (170, 4),
#   (171, 6),
#   (172, 10),
#   (173, 7),
#   (174, 2),
#   (175, 4),
#   (176, 3),
#   (177, 4),
#   (178, 1),
#   (179, 3),
#   (180, 1),
#   (181, 2),
#   (182, 3),
#   (183, 2),
#   (184, 1),
#   (185, 1),
#   (186, 3),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 1),
#   (191, 4),
#   (192, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 2),
#   (198, 1),
#   (199, 1),
#   (200, 1),
#   (201, 1),
#   (202, 1),
#   (203, 3),
#   (204, 1),
#   (205, 1),
#   (206, 2),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 1),
#   (214, 2),
#   (215, 1),
#   (216, 1),
#   (217, 1),
#   (218, 2),
#   (219, 1),
#   (220, 3),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 4),
#   (226, 2),
#   (227, 1),
#   (228, 3),
#   (229, 2),
#   (230, 1),
#   (231, 2),
#   (232, 1),
#   (233, 1),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (237, 1),
#   (238, 1),
#   (239, 1),
#   (240, 5),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 3),
#   (245, 1),
#   (246, 2),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 2),
#   (251, 2),
#   (252, 1),
#   (253, 1),
#   (254, 4),
#   (255, 3),
#   (256, 1),
#   (257, 1),
#   (258, 2),
#   (259, 1),
#   (260, 1),
#   (261, 1),
#   (262, 2),
#   (263, 1),
#   (264, 1),
#   (265, 2),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 16),
#   (271, 1),
#   (272, 1),
#   (273, 1),
#   (274, 2),
#   (275, 1),
#   (276, 1),
#   (277, 3),
#   (278, 2),
#   (279, 1),
#   (280, 1),
#   (281, 4),
#   (282, 6),
#   (283, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (287, 2),
#   (288, 5),
#   (289, 2),
#   (290, 1),
#   (291, 2),
#   (292, 1),
#   (293, 1),
#   (294, 1),
#   (295, 4),
#   (296, 1),
#   (297, 1),
#   (298, 5),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 2),
#   (304, 2),
#   (305, 1),
#   (306, 5),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 2),
#   (311, 2),
#   (312, 1),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1),
#   (320, 2),
#   (321, 2),
#   (322, 1),
#   (323, 5),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 4),
#   (331, 4),
#   (332, 1),
#   (333, 1),
#   (334, 1),
#   (335, 1),
#   (336, 2),
#   (337, 1),
#   (338, 2),
#   (339, 8),
#   (340, 1),
#   (341, 1),
#   (342, 1),
#   (343, 2),
#   (344, 3),
#   (345, 3),
#   (346, 2),
#   (347, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1),
#   (351, 2),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 2),
#   (358, 1),
#   (359, 1),
#   (360, 3),
#   (361, 1),
#   (362, 1),
#   (363, 1),
#   (364, 5),
#   (365, 3),
#   (366, 2),
#   (367, 2),
#   (368, 1),
#   (369, 2),
#   (370, 4),
#   (371, 5),
#   (372, 1),
#   (373, 1),
#   (374, 1),
#   (375, 1),
#   (376, 2),
#   (377, 1),
#   (378, 1),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 2),
#   (383, 1),
#   (384, 1),
#   (385, 2),
#   (386, 6),
#   (387, 1),
#   (388, 3),
#   (389, 7),
#   (390, 1),
#   (391, 1),
#   (392, 1),
#   (393, 3),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 2),
#   (398, 1),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 2),
#   (403, 5),
#   (404, 1),
#   (405, 1),
#   (406, 1),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1),
#   (411, 2),
#   (412, 2),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 1),
#   (419, 2),
#   (420, 1),
#   (421, 1),
#   (422, 4),
#   (423, 1),
#   (424, 1),
#   (425, 1),
#   (426, 1),
#   (427, 3),
#   (428, 1),
#   (429, 1),
#   (430, 1),
#   (431, 1),
#   (432, 1),
#   (433, 1),
#   (434, 2),
#   (435, 5),
#   (436, 1),
#   (437, 3),
#   (438, 1),
#   (439, 1),
#   (440, 2),
#   (441, 1),
#   (442, 1),
#   (443, 3),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 1),
#   (451, 1),
#   (452, 3),
#   (453, 2),
#   (454, 2),
#   (455, 1),
#   (456, 1),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 5),
#   (461, 3),
#   (462, 1),
#   (463, 1),
#   (464, 1),
#   (465, 1),
#   (466, 1),
#   (467, 2),
#   (468, 3),
#   (469, 3),
#   (470, 1),
#   (471, 1),
#   (472, 1),
#   (473, 1),
#   (474, 19),
#   (475, 25),
#   (476, 3),
#   (477, 1),
#   (478, 1),
#   (479, 2),
#   (480, 1),
#   (481, 1),
#   (482, 1),
#   (483, 1),
#   (484, 1),
#   (485, 1),
#   (486, 7),
#   (487, 8),
#   (488, 1),
#   (489, 1),
#   (490, 2),
#   (491, 1),
#   (492, 1),
#   (493, 1),
#   (494, 3),
#   (495, 3),
#   (496, 1),
#   (497, 1),
#   (498, 1),
#   (499, 6),
#   (500, 1),
#   (501, 2),
#   (502, 1),
#   (503, 1),
#   (504, 1),
#   (505, 1),
#   (506, 2),
#   (507, 1),
#   (508, 1),
#   (509, 1),
#   (510, 1),
#   (511, 1),
#   (512, 4),
#   (513, 2),
#   (514, 1),
#   (515, 1),
#   (516, 1),
#   (517, 5),
#   (518, 1),
#   (519, 2),
#   (520, 1),
#   (521, 2),
#   (522, 3),
#   (523, 2),
#   (524, 1),
#   (525, 4),
#   (526, 2),
#   (527, 2),
#   (528, 1),
#   (529, 6),
#   (530, 1),
#   (531, 1),
#   (532, 3),
#   (533, 10),
#   (534, 1),
#   (535, 2),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 3),
#   (541, 1),
#   (542, 2),
#   (543, 1),
#   (544, 3),
#   (545, 9),
#   (546, 15),
#   (547, 9),
#   (548, 1),
#   (549, 1),
#   (550, 2),
#   (551, 1),
#   (552, 1),
#   (553, 1),
#   (554, 2),
#   (555, 1),
#   (556, 1),
#   (557, 1),
#   (558, 1),
#   (559, 1),
#   (560, 1),
#   (561, 2),
#   (562, 1),
#   (563, 1),
#   (564, 2),
#   (565, 2),
#   (566, 1),
#   (567, 5),
#   (568, 1),
#   (569, 1),
#   (570, 1),
#   (571, 1),
#   (572, 1),
#   (573, 7),
#   (574, 1),
#   (575, 2),
#   (576, 9),
#   (577, 1),
#   (578, 3),
#   (579, 2),
#   (580, 2),
#   (581, 1),
#   (582, 1),
#   (583, 9),
#   (584, 2),
#   (585, 1),
#   (586, 8),
#   (587, 4),
#   (588, 1),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 1),
#   (593, 1),
#   (594, 32),
#   (595, 1),
#   (596, 1),
#   (597, 4),
#   (598, 1),
#   (599, 2),
#   (600, 1),
#   (601, 1),
#   (602, 2),
#   (603, 1),
#   (604, 2),
#   (605, 1),
#   (606, 2),
#   (607, 1),
#   (608, 7),
#   (609, 1),
#   (610, 1),
#   (611, 1),
#   (612, 2),
#   (613, 1),
#   (614, 1),
#   (615, 2),
#   (616, 1),
#   (617, 1),
#   (618, 1),
#   (619, 1),
#   (620, 3),
#   (621, 2),
#   (622, 1),
#   (623, 1),
#   (624, 1),
#   (625, 1),
#   (626, 1),
#   (627, 1),
#   (628, 3),
#   (629, 1),
#   (630, 2),
#   (631, 4),
#   (632, 1),
#   (633, 1),
#   (634, 1),
#   (635, 1),
#   (636, 1),
#   (637, 1),
#   (638, 1),
#   (639, 1),
#   (640, 1),
#   (641, 3),
#   (642, 2),
#   (643, 2),
#   (644, 1),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 2),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 1),
#   (653, 1),
#   (654, 6),
#   (655, 96),
#   (656, 1),
#   (657, 1),
#   (658, 2),
#   (659, 1),
#   (660, 1),
#   (661, 4),
#   (662, 1),
#   (663, 2),
#   (664, 2),
#   (665, 8),
#   (666, 2),
#   (667, 1),
#   (668, 2),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 4),
#   (674, 1),
#   (675, 15),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 2),
#   (680, 1),
#   (681, 1),
#   (682, 1),
#   (683, 3),
#   (684, 3),
#   (685, 6),
#   (686, 2),
#   (687, 1),
#   (688, 4),
#   (689, 1),
#   (690, 2),
#   (691, 1),
#   (692, 1),
#   (693, 1),
#   (694, 2),
#   (695, 1),
#   (696, 1),
#   (697, 2),
#   (698, 1),
#   (699, 11),
#   (700, 2),
#   (701, 1),
#   (702, 6),
#   (703, 1),
#   (704, 1),
#   (705, 1),
#   (706, 1),
#   (707, 6),
#   (708, 1),
#   (709, 1),
#   (710, 1),
#   (711, 2),
#   (712, 1),
#   (713, 1),
#   (714, 1),
#   (715, 1),
#   (716, 2),
#   (717, 1),
#   (718, 1),
#   (719, 1),
#   (720, 1),
#   (721, 34),
#   (722, 1),
#   (723, 2),
#   (724, 1),
#   (725, 2),
#   (726, 3),
#   (727, 1),
#   (728, 1),
#   (729, 1),
#   (730, 1),
#   (731, 1),
#   (732, 1),
#   (733, 2),
#   (734, 1),
#   (735, 1),
#   (736, 1),
#   (737, 1),
#   (738, 1),
#   (739, 1),
#   (740, 17),
#   (741, 1),
#   (742, 3),
#   (743, 1),
#   (744, 1),
#   (745, 2),
#   (746, 3),
#   (747, 2),
#   (748, 1),
#   (749, 3),
#   (750, 5),
#   (751, 1),
#   (752, 4),
#   (753, 4),
#   (754, 1),
#   (755, 4),
#   (756, 1),
#   (757, 1),
#   (758, 1),
#   (759, 1),
#   (760, 1),
#   (761, 6),
#   (762, 1),
#   (763, 1),
#   (764, 1),
#   (765, 6),
#   (766, 1),
#   (767, 1),
#   (768, 2),
#   (769, 1),
#   (770, 2),
#   (771, 3),
#   (772, 1),
#   (773, 11),
#   (774, 5),
#   (775, 7),
#   (776, 4),
#   (777, 1),
#   (778, 3),
#   (779, 1),
#   (780, 1),
#   (781, 4),
#   (782, 1),
#   (783, 1),
#   (784, 1),
#   (785, 1),
#   (786, 1),
#   (787, 1),
#   (788, 1),
#   (789, 4),
#   (790, 1),
#   (791, 1),
#   (792, 5),
#   (793, 4),
#   (794, 2),
#   (795, 1),
#   (796, 1),
#   (797, 1),
#   (798, 4),
#   (799, 1),
#   (800, 1),
#   (801, 1),
#   (802, 1),
#   (803, 6),
#   (804, 2),
#   (805, 1),
#   (806, 2),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 1),
#   (812, 3),
#   (813, 1),
#   (814, 1),
#   (815, 1),
#   (816, 1),
#   (817, 1),
#   (818, 3),
#   (819, 3),
#   (820, 1),
#   (821, 6),
#   (822, 1),
#   (823, 51),
#   (824, 11),
#   (825, 1),
#   (826, 1),
#   (827, 1),
#   (828, 17),
#   (829, 76),
#   (830, 8),
#   (831, 3),
#   (832, 1),
#   (833, 1),
#   (834, 1),
#   (835, 1),
#   (836, 9),
#   (837, 5),
#   (838, 1),
#   (839, 1),
#   (840, 8),
#   (841, 1),
#   (842, 1),
#   (843, 1),
#   (844, 3),
#   (845, 2),
#   (846, 1),
#   (847, 1),
#   (848, 1),
#   (849, 2),
#   (850, 2),
#   (851, 1),
#   (852, 1),
#   (853, 1),
#   (854, 1),
#   (855, 3),
#   (856, 1),
#   (857, 4),
#   (858, 1),
#   (859, 2),
#   (860, 3),
#   (861, 1),
#   (862, 1),
#   (863, 1),
#   (864, 1),
#   (865, 1),
#   (866, 1),
#   (867, 1),
#   (868, 1),
#   (869, 1),
#   (870, 28),
#   (871, 1),
#   (872, 1),
#   (873, 1),
#   (874, 1),
#   (875, 1),
#   (876, 1),
#   (877, 1),
#   (878, 1),
#   (879, 1),
#   (880, 1),
#   (881, 1),
#   (882, 1),
#   (883, 2),
#   (884, 1),
#   (885, 1),
#   (886, 2),
#   (887, 5),
#   (888, 1),
#   (889, 1),
#   (890, 1),
#   (891, 4),
#   (892, 1),
#   (893, 1),
#   (894, 1),
#   (895, 4),
#   (896, 1),
#   (897, 1),
#   (898, 2),
#   (899, 1),
#   (900, 1),
#   (901, 4),
#   (902, 3),
#   (903, 1),
#   (904, 1),
#   (905, 1),
#   (906, 1),
#   (907, 1),
#   (908, 1),
#   (909, 2),
#   (910, 14),
#   (911, 14),
#   (912, 2),
#   (913, 1),
#   (914, 1),
#   (915, 2),
#   (916, 2),
#   (917, 1),
#   (918, 1),
#   (919, 1),
#   (920, 1),
#   (921, 3),
#   (922, 1),
#   (923, 4),
#   (924, 1),
#   (925, 1),
#   (926, 3),
#   (927, 1),
#   (928, 3),
#   (929, 1),
#   (930, 1),
#   (931, 2),
#   (932, 1),
#   (933, 1),
#   (934, 1),
#   (935, 3),
#   (936, 1),
#   (937, 1),
#   (938, 1),
#   (939, 2),
#   (940, 1),
#   (941, 1),
#   (942, 1),
#   (943, 1),
#   (944, 1),
#   (945, 1),
#   (946, 2),
#   (947, 1),
#   (948, 1),
#   (949, 3),
#   (950, 3),
#   (951, 1),
#   (952, 1),
#   (953, 2),
#   (954, 3),
#   (955, 1),
#   (956, 1),
#   (957, 2),
#   (958, 2),
#   (959, 2),
#   (960, 1),
#   (961, 1),
#   (962, 1),
#   (963, 1),
#   (964, 1),
#   (965, 3),
#   (966, 4),
#   (967, 1),
#   (968, 1),
#   (969, 7),
#   (970, 1),
#   (971, 2),
#   (972, 1),
#   (973, 1),
#   (974, 1),
#   (975, 2),
#   (976, 1),
#   (977, 6),
#   (978, 1),
#   (979, 1),
#   (980, 1),
#   (981, 1),
#   (982, 1),
#   (983, 3),
#   (984, 1),
#   (985, 3),
#   (986, 1),
#   (987, 8),
#   (988, 3),
#   (989, 3),
#   (990, 1),
#   (991, 2),
#   (992, 1),
#   (993, 4),
#   (994, 1),
#   (995, 1),
#   (996, 41),
#   (997, 3),
#   (998, 1),
#   (999, 1),
#   ...],
#  [(4, 3),
#   (6, 1),
#   (8, 11),
#   (9, 1),
#   (10, 1),
#   (13, 5),
#   (19, 1),
#   (24, 1),
#   (29, 2),
#   (30, 1),
#   (39, 1),
#   (40, 1),
#   (42, 1),
#   (43, 1),
#   (44, 2),
#   (46, 1),
#   (48, 1),
#   (49, 4),
#   (55, 3),
#   (57, 1),
#   (59, 1),
#   (61, 5),
#   (62, 1),
#   (63, 3),
#   (64, 4),
#   (66, 1),
#   (69, 3),
#   (77, 2),
#   (79, 1),
#   (88, 1),
#   (89, 4),
#   (113, 2),
#   (114, 1),
#   (117, 1),
#   (120, 2),
#   (121, 1),
#   (122, 2),
#   (125, 1),
#   (134, 3),
#   (136, 4),
#   (141, 1),
#   (147, 1),
#   (151, 5),
#   (153, 1),
#   (156, 2),
#   (157, 2),
#   (168, 2),
#   (171, 4),
#   (172, 10),
#   (173, 3),
#   (179, 1),
#   (183, 1),
#   (190, 1),
#   (191, 2),
#   (214, 2),
#   (220, 3),
#   (222, 2),
#   (223, 1),
#   (225, 2),
#   (226, 1),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (232, 1),
#   (235, 1),
#   (237, 2),
#   (240, 2),
#   (245, 1),
#   (246, 1),
#   (253, 1),
#   (254, 1),
#   (258, 4),
#   (259, 1),
#   (270, 2),
#   (271, 2),
#   (277, 3),
#   (279, 1),
#   (287, 3),
#   (288, 11),
#   (296, 1),
#   (298, 10),
#   (299, 1),
#   (306, 3),
#   (319, 2),
#   (320, 5),
#   (321, 5),
#   (323, 1),
#   (324, 1),
#   (330, 2),
#   (331, 2),
#   (338, 4),
#   (339, 7),
#   (340, 1),
#   (344, 4),
#   (346, 3),
#   (351, 1),
#   (358, 1),
#   (359, 4),
#   (360, 1),
#   (363, 4),
#   (364, 2),
#   (365, 1),
#   (366, 1),
#   (368, 3),
#   (369, 1),
#   (385, 1),
#   (389, 5),
#   (390, 1),
#   (392, 4),
#   (393, 3),
#   (402, 1),
#   (403, 4),
#   (411, 2),
#   (413, 3),
#   (419, 2),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (427, 5),
#   (435, 8),
#   (449, 1),
#   (450, 2),
#   (451, 1),
#   (453, 1),
#   (459, 1),
#   (462, 1),
#   (467, 1),
#   (469, 5),
#   (494, 9),
#   (495, 1),
#   (499, 2),
#   (503, 1),
#   (505, 2),
#   (506, 1),
#   (513, 4),
#   (515, 1),
#   (521, 2),
#   (522, 2),
#   (542, 1),
#   (544, 1),
#   (545, 13),
#   (552, 1),
#   (554, 3),
#   (556, 2),
#   (562, 1),
#   (565, 2),
#   (566, 1),
#   (567, 4),
#   (573, 9),
#   (574, 1),
#   (575, 4),
#   (576, 9),
#   (581, 4),
#   (583, 13),
#   (595, 1),
#   (598, 1),
#   (599, 1),
#   (600, 1),
#   (602, 4),
#   (606, 7),
#   (608, 15),
#   (612, 1),
#   (616, 1),
#   (632, 1),
#   (633, 1),
#   (639, 3),
#   (646, 6),
#   (648, 1),
#   (651, 1),
#   (653, 2),
#   (654, 2),
#   (655, 1),
#   (657, 1),
#   (661, 2),
#   (662, 6),
#   (665, 3),
#   (667, 3),
#   (673, 5),
#   (679, 2),
#   (684, 1),
#   (686, 1),
#   (688, 2),
#   (691, 6),
#   (695, 1),
#   (697, 2),
#   (707, 9),
#   (715, 2),
#   (720, 14),
#   (721, 8),
#   (723, 3),
#   (725, 1),
#   (738, 1),
#   (740, 1),
#   (741, 1),
#   (748, 2),
#   (752, 3),
#   (762, 1),
#   (764, 8),
#   (771, 4),
#   (780, 3),
#   (789, 1),
#   (791, 5),
#   (792, 2),
#   (794, 1),
#   (801, 15),
#   (806, 1),
#   (807, 1),
#   (809, 1),
#   (811, 4),
#   (814, 2),
#   (816, 2),
#   (818, 2),
#   (828, 1),
#   (836, 2),
#   (840, 5),
#   (844, 1),
#   (853, 4),
#   (854, 1),
#   (855, 1),
#   (860, 3),
#   (867, 4),
#   (872, 1),
#   (879, 3),
#   (882, 1),
#   (883, 1),
#   (885, 8),
#   (886, 1),
#   (888, 1),
#   (900, 1),
#   (903, 1),
#   (910, 1),
#   (915, 1),
#   (916, 6),
#   (921, 3),
#   (922, 2),
#   (923, 1),
#   (928, 2),
#   (929, 12),
#   (930, 1),
#   (931, 2),
#   (938, 2),
#   (954, 7),
#   (958, 3),
#   (961, 2),
#   (963, 1),
#   (969, 4),
#   (970, 1),
#   (983, 6),
#   (995, 2),
#   (997, 1),
#   (999, 1),
#   (1009, 2),
#   (1010, 1),
#   (1027, 3),
#   (1029, 1),
#   (1031, 1),
#   (1040, 1),
#   (1042, 1),
#   (1045, 1),
#   (1046, 1),
#   (1056, 34),
#   (1061, 2),
#   (1062, 5),
#   (1063, 1),
#   (1066, 2),
#   (1087, 1),
#   (1089, 4),
#   (1104, 1),
#   (1106, 1),
#   (1109, 4),
#   (1110, 1),
#   (1111, 3),
#   (1122, 1),
#   (1123, 1),
#   (1127, 5),
#   (1138, 36),
#   (1144, 1),
#   (1154, 4),
#   (1172, 1),
#   (1173, 1),
#   (1176, 1),
#   (1183, 2),
#   (1193, 4),
#   (1194, 1),
#   (1195, 6),
#   (1196, 1),
#   (1199, 2),
#   (1200, 6),
#   (1202, 1),
#   (1203, 1),
#   (1204, 1),
#   (1205, 1),
#   (1206, 3),
#   (1214, 2),
#   (1225, 1),
#   (1226, 3),
#   (1229, 2),
#   (1233, 12),
#   (1234, 1),
#   (1240, 1),
#   (1243, 1),
#   (1244, 1),
#   (1245, 1),
#   (1246, 2),
#   (1247, 1),
#   (1248, 1),
#   (1249, 1),
#   (1250, 1),
#   (1251, 1),
#   (1252, 1),
#   (1253, 1),
#   (1254, 1),
#   (1255, 3),
#   (1256, 1),
#   (1257, 2),
#   (1258, 2),
#   (1259, 2),
#   (1260, 1),
#   (1261, 1),
#   (1262, 1),
#   (1263, 1),
#   (1264, 1),
#   (1265, 5),
#   (1266, 2),
#   (1267, 2),
#   (1268, 1),
#   (1269, 1),
#   (1270, 1),
#   (1271, 5),
#   (1272, 1),
#   (1273, 1),
#   (1274, 1),
#   (1275, 1),
#   (1276, 1),
#   (1277, 1),
#   (1278, 1),
#   (1279, 1),
#   (1280, 1),
#   (1281, 3),
#   (1282, 3),
#   (1283, 3),
#   (1284, 1),
#   (1285, 1),
#   (1286, 1),
#   (1287, 1),
#   (1288, 1),
#   (1289, 2),
#   (1290, 1),
#   (1291, 1),
#   (1292, 1),
#   (1293, 1),
#   (1294, 1),
#   (1295, 4),
#   (1296, 1),
#   (1297, 1),
#   (1298, 1),
#   (1299, 5),
#   (1300, 1),
#   (1301, 3),
#   (1302, 1),
#   (1303, 1),
#   (1304, 1),
#   (1305, 1),
#   (1306, 1),
#   (1307, 1),
#   (1308, 1),
#   (1309, 1),
#   (1310, 1),
#   (1311, 1),
#   (1312, 1),
#   (1313, 1),
#   (1314, 2),
#   (1315, 1),
#   (1316, 1),
#   (1317, 3),
#   (1318, 2),
#   (1319, 1),
#   (1320, 1),
#   (1321, 2),
#   (1322, 1),
#   (1323, 2),
#   (1324, 1),
#   (1325, 1),
#   (1326, 1),
#   (1327, 1),
#   (1328, 2),
#   (1329, 1),
#   (1330, 1),
#   (1331, 1),
#   (1332, 1),
#   (1333, 1),
#   (1334, 1),
#   (1335, 2),
#   (1336, 5),
#   (1337, 1),
#   (1338, 1),
#   (1339, 1),
#   (1340, 1),
#   (1341, 1),
#   (1342, 1),
#   (1343, 3),
#   (1344, 2),
#   (1345, 1),
#   (1346, 3),
#   (1347, 2),
#   (1348, 1),
#   (1349, 2),
#   (1350, 1),
#   (1351, 1),
#   (1352, 1),
#   (1353, 2),
#   (1354, 1),
#   (1355, 1),
#   (1356, 1),
#   (1357, 3),
#   (1358, 1),
#   (1359, 1),
#   (1360, 8),
#   (1361, 1),
#   (1362, 2),
#   (1363, 1),
#   (1364, 4),
#   (1365, 1),
#   (1366, 1),
#   (1367, 1),
#   (1368, 1),
#   (1369, 1),
#   (1370, 1),
#   (1371, 1),
#   (1372, 2),
#   (1373, 1),
#   (1374, 2),
#   (1375, 1),
#   (1376, 1),
#   (1377, 2),
#   (1378, 1),
#   (1379, 2),
#   (1380, 3),
#   (1381, 1),
#   (1382, 1),
#   (1383, 1),
#   (1384, 1),
#   (1385, 2),
#   (1386, 1),
#   (1387, 1),
#   (1388, 1),
#   (1389, 1),
#   (1390, 3),
#   (1391, 2),
#   (1392, 1),
#   (1393, 3),
#   (1394, 1),
#   (1395, 2),
#   (1396, 10),
#   (1397, 1),
#   (1398, 1),
#   (1399, 1),
#   (1400, 1),
#   (1401, 1),
#   (1402, 1),
#   (1403, 2),
#   (1404, 1),
#   (1405, 2),
#   (1406, 1),
#   (1407, 1),
#   (1408, 8),
#   (1409, 3),
#   (1410, 1),
#   (1411, 3),
#   (1412, 1),
#   (1413, 1),
#   (1414, 1),
#   (1415, 3),
#   (1416, 1),
#   (1417, 2),
#   (1418, 1),
#   (1419, 1),
#   (1420, 1),
#   (1421, 2),
#   (1422, 1),
#   (1423, 5),
#   (1424, 1),
#   (1425, 1),
#   (1426, 1),
#   (1427, 1),
#   (1428, 1),
#   (1429, 1),
#   (1430, 1),
#   (1431, 1),
#   (1432, 1),
#   (1433, 5),
#   (1434, 3),
#   (1435, 1),
#   (1436, 3),
#   (1437, 1),
#   (1438, 4),
#   (1439, 4),
#   (1440, 1),
#   (1441, 30),
#   (1442, 6),
#   (1443, 1),
#   (1444, 1),
#   (1445, 1),
#   (1446, 1),
#   (1447, 1),
#   (1448, 1),
#   (1449, 1),
#   (1450, 1),
#   (1451, 3),
#   (1452, 1),
#   (1453, 2),
#   (1454, 1),
#   (1455, 1),
#   (1456, 1),
#   (1457, 1),
#   (1458, 1),
#   (1459, 1),
#   (1460, 1),
#   (1461, 1),
#   (1462, 1),
#   (1463, 1),
#   (1464, 1),
#   (1465, 1),
#   (1466, 1),
#   (1467, 2),
#   (1468, 1),
#   (1469, 1),
#   (1470, 1),
#   (1471, 2),
#   (1472, 1),
#   (1473, 2),
#   (1474, 3),
#   (1475, 1),
#   (1476, 1),
#   (1477, 1),
#   (1478, 1),
#   (1479, 1),
#   (1480, 1),
#   (1481, 7),
#   (1482, 1),
#   (1483, 1),
#   (1484, 1),
#   (1485, 2),
#   (1486, 9),
#   (1487, 2),
#   (1488, 2),
#   (1489, 1),
#   (1490, 1),
#   (1491, 1),
#   (1492, 1),
#   (1493, 1),
#   (1494, 3),
#   (1495, 3),
#   (1496, 1),
#   (1497, 1),
#   (1498, 15),
#   (1499, 2),
#   (1500, 1),
#   (1501, 1),
#   (1502, 1),
#   (1503, 1),
#   (1504, 1),
#   (1505, 1),
#   (1506, 1),
#   (1507, 1),
#   (1508, 1),
#   (1509, 1),
#   (1510, 6),
#   (1511, 1),
#   (1512, 1),
#   (1513, 1),
#   (1514, 1),
#   (1515, 1),
#   (1516, 3),
#   (1517, 1),
#   (1518, 1),
#   (1519, 1),
#   (1520, 1),
#   (1521, 2),
#   (1522, 1),
#   (1523, 1),
#   (1524, 1),
#   (1525, 2),
#   (1526, 1),
#   (1527, 1),
#   (1528, 1),
#   (1529, 1),
#   (1530, 3),
#   (1531, 1),
#   (1532, 1),
#   (1533, 1),
#   (1534, 1),
#   (1535, 1),
#   (1536, 1),
#   (1537, 1),
#   (1538, 1),
#   (1539, 1),
#   (1540, 3),
#   (1541, 1),
#   (1542, 4),
#   (1543, 1),
#   (1544, 1),
#   (1545, 3),
#   (1546, 3),
#   (1547, 1),
#   (1548, 1),
#   (1549, 1),
#   (1550, 1),
#   (1551, 1),
#   (1552, 1),
#   (1553, 1),
#   (1554, 1),
#   (1555, 1),
#   (1556, 1),
#   (1557, 1),
#   (1558, 2),
#   (1559, 2),
#   (1560, 9),
#   (1561, 2),
#   (1562, 1),
#   (1563, 1),
#   (1564, 2),
#   (1565, 2),
#   (1566, 1),
#   (1567, 1),
#   (1568, 2),
#   (1569, 2),
#   (1570, 1),
#   (1571, 3),
#   (1572, 1),
#   (1573, 1),
#   (1574, 2),
#   (1575, 1),
#   (1576, 4),
#   (1577, 3),
#   (1578, 1),
#   (1579, 1),
#   (1580, 2),
#   (1581, 29),
#   (1582, 1),
#   (1583, 1),
#   (1584, 1),
#   (1585, 1),
#   (1586, 1),
#   (1587,

#   (1861, 1),
#   (1862, 1),
#   (1863, 1),
#   (1864, 1),
#   (1865, 1),
#   (1866, 1),
#   (1867, 1),
#   (1868, 1),
#   (1869, 1),
#   (1870, 1),
#   (1871, 2),
#   (1872, 1),
#   (1873, 1),
#   (1874, 1),
#   (1875, 1),
#   (1876, 1),
#   (1877, 1),
#   (1878, 1),
#   (1879, 1),
#   (1880, 4),
#   (1881, 1),
#   (1882, 2),
#   (1883, 1),
#   (1884, 2),
#   (1885, 1),
#   (1886, 1),
#   (1887, 2),
#   (1888, 1),
#   (1889, 1),
#   (1890, 1),
#   (1891, 1),
#   (1892, 1),
#   (1893, 1),
#   (1894, 2),
#   (1895, 2),
#   (1896, 1),
#   (1897, 1),
#   (1898, 2),
#   (1899, 1),
#   (1900, 2),
#   (1901, 3),
#   (1902, 1),
#   (1903, 1),
#   (1904, 1),
#   (1905, 1),
#   (1906, 1),
#   (1907, 1),
#   (1908, 16),
#   (1909, 3),
#   (1910, 1),
#   (1911, 1),
#   (1912, 1),
#   (1913, 1),
#   (1914, 2),
#   (1915, 1),
#   (1916, 1),
#   (1917, 1),
#   (1918, 1),
#   (1919, 2),
#   (1920, 2),
#   (1921, 1),
#   (1922, 1),
#   (1923, 1),
#   (1924, 1),
#   (1925, 2),
#   (1926, 1),
#   (1927, 28),
#   (1928, 1),
#   (1929, 1),
#   (1930, 1),
#   (1931, 1),
#   (1932, 1),
#   (1933, 1),
#   (1934, 1),
#   (1935, 1),
#   (1936, 1),
#   (1937, 2),
#   (1938, 4),
#   (1939, 1),
#   (1940, 1),
#   (1941, 1),
#   (1942, 1),
#   ...],
#  [(2, 1),
#   (8, 1),
#   (9, 1),
#   (12, 1),
#   (14, 10),
#   (15, 2),
#   (18, 2),
#   (19, 1),
#   (24, 4),
#   (26, 1),
#   (38, 2),
#   (39, 3),
#   (40, 1),
#   (44, 8),
#   (45, 2),
#   (47, 16),
#   (48, 2),
#   (49, 1),
#   (50, 3),
#   (58, 1),
#   (59, 1),
#   (60, 1),
#   (62, 3),
#   (64, 3),
#   (77, 1),
#   (90, 1),
#   (97, 1),
#   (113, 3),
#   (116, 1),
#   (117, 1),
#   (119, 3),
#   (120, 1),
#   (124, 1),
#   (125, 2),
#   (126, 3),
#   (134, 1),
#   (136, 7),
#   (143, 1),
#   (150, 1),
#   (151, 9),
#   (168, 5),
#   (171, 1),
#   (172, 10),
#   (179, 2),
#   (195, 1),
#   (205, 1),
#   (208, 4),
#   (213, 1),
#   (220, 2),
#   (221, 3),
#   (225, 1),
#   (229, 1),
#   (232, 2),
#   (233, 1),
#   (235, 2),
#   (237, 3),
#   (246, 2),
#   (256, 1),
#   (259, 4),
#   (271, 2),
#   (277, 3),
#   (278, 3),
#   (284, 1),
#   (287, 1),
#   (288, 3),
#   (289, 2),
#   (295, 1),
#   (306, 1),
#   (314, 3),
#   (319, 4),
#   (320, 2),
#   (322, 1),
#   (326, 1),
#   (327, 2),
#   (330, 5),
#   (331, 4),
#   (337, 1),
#   (339, 4),
#   (345, 1),
#   (346, 3),
#   (351, 7),
#   (353, 4),
#   (354, 1),
#   (357, 6),
#   (358, 2),
#   (363, 1),
#   (364, 2),
#   (369, 1),
#   (380, 2),
#   (382, 1),
#   (386, 1),
#   (388, 1),
#   (389, 2),
#   (393, 9),
#   (394, 1),
#   (395, 1),
#   (396, 3),
#   (397, 1),
#   (403, 1),
#   (406, 2),
#   (412, 1),
#   (415, 4),
#   (419, 2),
#   (425, 2),
#   (427, 1),
#   (430, 1),
#   (431, 3),
#   (432, 15),
#   (433, 1),
#   (435, 2),
#   (438, 2),
#   (442, 2),
#   (443, 2),
#   (446, 1),
#   (448, 1),
#   (450, 2),
#   (453, 1),
#   (482, 1),
#   (485, 1),
#   (486, 1),
#   (494, 14),
#   (495, 9),
#   (499, 1),
#   (502, 1),
#   (505, 1),
#   (506, 5),
#   (512, 3),
#   (513, 2),
#   (516, 1),
#   (519, 1),
#   (525, 3),
#   (529, 1),
#   (537, 2),
#   (539, 1),
#   (542, 1),
#   (543, 1),
#   (545, 7),
#   (554, 3),
#   (565, 3),
#   (567, 7),
#   (573, 15),
#   (574, 3),
#   (575, 2),
#   (576, 10),
#   (579, 1),
#   (580, 2),
#   (583, 1),
#   (595, 1),
#   (599, 1),
#   (600, 1),
#   (606, 4),
#   (608, 1),
#   (612, 1),
#   (613, 1),
#   (615, 2),
#   (616, 2),
#   (619, 1),
#   (620, 2),
#   (632, 2),
#   (633, 4),
#   (644, 1),
#   (651, 1),
#   (654, 2),
#   (665, 2),
#   (666, 2),
#   (667, 1),
#   (668, 3),
#   (673, 2),
#   (684, 4),
#   (685, 2),
#   (686, 5),
#   (688, 2),
#   (689, 1),
#   (691, 1),
#   (697, 4),
#   (699, 1),
#   (700, 1),
#   (702, 2),
#   (707, 8),
#   (713, 1),
#   (715, 3),
#   (723, 2),
#   (725, 7),
#   (729, 1),
#   (738, 2),
#   (740, 4),
#   (741, 1),
#   (748, 1),
#   (764, 1),
#   (765, 4),
#   (767, 2),
#   (768, 2),
#   (769, 1),
#   (770, 2),
#   (775, 6),
#   (776, 1),
#   (792, 3),
#   (793, 3),
#   (794, 1),
#   (801, 1),
#   (814, 13),
#   (818, 12),
#   (840, 7),
#   (843, 2),
#   (844, 1),
#   (845, 2),
#   (852, 1),
#   (853, 1),
#   (855, 2),
#   (859, 1),
#   (860, 1),
#   (867, 7),
#   (868, 9),
#   (869, 1),
#   (870, 3),
#   (872, 2),
#   (878, 1),
#   (882, 1),
#   (883, 2),
#   (888, 1),
#   (893, 1),
#   (895, 1),
#   (900, 4),
#   (905, 1),
#   (906, 1),
#   (911, 3),
#   (915, 1),
#   (916, 1),
#   (918, 2),
#   (920, 1),
#   (923, 1),
#   (928, 1),
#   (929, 1),
#   (931, 3),
#   (933, 1),
#   (934, 1),
#   (941, 1),
#   (943, 2),
#   (956, 2),
#   (958, 6),
#   (969, 10),
#   (971, 2),
#   (988, 1),
#   (1013, 13),
#   (1018, 2),
#   (1019, 2),
#   (1024, 2),
#   (1027, 4),
#   (1030, 1),
#   (1036, 2),
#   (1041, 9),
#   (1044, 3),
#   (1046, 1),
#   (1061, 2),
#   (1062, 7),
#   (1063, 1),
#   (1064, 1),
#   (1065, 1),
#   (1066, 2),
#   (1067, 1),
#   (1080, 1),
#   (1083, 1),
#   (1084, 2),
#   (1086, 1),
#   (1087, 2),
#   (1090, 1),
#   (1103, 1),
#   (1109, 8),
#   (1111, 5),
#   (1113, 1),
#   (1114, 1),
#   (1118, 1),
#   (1123, 1),
#   (1124, 1),
#   (1127, 1),
#   (1128, 3),
#   (1138, 24),
#   (1144, 1),
#   (1153, 1),
#   (1169, 1),
#   (1171, 1),
#   (1172, 1),
#   (1176, 1),
#   (1179, 1),
#   (1182, 1),
#   (1183, 3),
#   (1200, 2),
#   (1203, 2),
#   (1205, 3),
#   (1206, 2),
#   (1209, 1),
#   (1213, 1),
#   (1222, 1),
#   (1225, 2),
#   (1226, 3),
#   (1228, 1),
#   (1229, 1),
#   (1233, 6),
#   (1234, 3),
#   (1246, 1),
#   (1253, 1),
#   (1255, 4),
#   (1265, 1),
#   (1267, 2),
#   (1270, 1),
#   (1278, 4),
#   (1279, 2),
#   (1280, 1),
#   (1283, 5),
#   (1305, 1),
#   (1326, 1),
#   (1331, 1),
#   (1333, 1),
#   (1351, 1),
#   (1353, 1),
#   (1354, 1),
#   (1358, 2),
#   (1362, 3),
#   (1364, 1),
#   (1365, 2),
#   (1368, 1),
#   (1372, 1),
#   (1383, 2),
#   (1384, 2),
#   (1389, 1),
#   (1390, 1),
#   (1393, 2),
#   (1395, 1),
#   (1397, 1),
#   (1407, 1),
#   (1415, 2),
#   (1424, 5),
#   (1436, 1),
#   (1444, 1),
#   (1445, 2),
#   (1450, 3),
#   (1462, 8),
#   (1471, 4),
#   (1490, 1),
#   (1494, 1),
#   (1495, 1),
#   (1496, 1),
#   (1515, 1),
#   (1519, 1),
#   (1521, 2),
#   (1522, 1),
#   (1531, 6),
#   (1532, 2),
#   (1534, 1),
#   (1535, 3),
#   (1540, 1),
#   (1545, 1),
#   (1553, 4),
#   (1554, 1),
#   (1565, 1),
#   (1566, 3),
#   (1590, 1),
#   (1600, 1),
#   (1616, 1),
#   (1622, 1),
#   (1628, 6),
#   (1672, 3),
#   (1678, 1),
#   (1687, 1),
#   (1695, 1),
#   (1719, 2),
#   (1724, 1),
#   (1757, 13),
#   (1758, 1),
#   (1774, 2),
#   (1775, 2),
#   (1777, 2),
#   (1804, 4),
#   (1812, 1),
#   (1815, 1),
#   (1824, 1),
#   (1825, 3),
#   (1828, 2),
#   (1834, 4),
#   (1836, 1),
#   (1838, 1),
#   (1839, 3),
#   (1841, 7),
#   (1856, 1),
#   (1865, 1),
#   (1870, 1),
#   (1871, 20),
#   (1878, 1),
#   (1881, 1),
#   (1884, 1),
#   (1895, 1),
#   (1898, 1),
#   (1908, 11),
#   (1909, 1),
#   (1910, 1),
#   (1914, 1),
#   (1915, 1),
#   (1925, 2),
#   (1927, 1),
#   (1943, 11),
#   (1955, 2),
#   (1965, 2),
#   (1972, 2),
#   (1974, 2),
#   (1975, 8),
#   (1980, 2),
#   (1983, 1),
#   (60, 1),
#   (64, 2),
#   (68, 1),
#   (69, 2),
#   (72, 1),
#   (77, 3),
#   (79, 2),
#   (88, 14),
#   (92, 3),
#   (100, 5),
#   (109, 70),
#   (110, 20),
#   (113, 6),
#   (114, 2),
#   (115, 2),
#   (118, 1),
#   (119, 9),
#   (120, 1),
#   (124, 1),
#   (125, 1),
#   (134, 8),
#   (136, 1),
#   (140, 1),
#   (141, 4),
#   (144, 1),
#   (151, 20),
#   (152, 1),
#   (153, 2),
#   (156, 5),
#   (159, 2),
#   (160, 2),
#   (164, 1),
#   (166, 2),
#   (167, 1),
#   (171, 1),
#   (172, 22),
#   (173, 6),
#   (174, 2),
#   (175, 2),
#   (176, 8),
#   (179, 8),
#   (189, 1),
#   (190, 3),
#   (201, 1),
#   (202, 2),
#   (213, 1),
#   (214, 1),
#   (220, 3),
#   (225, 1),
#   (226, 1),
#   (228, 13),
#   (229, 2),
#   (230, 3),
#   (235, 2),
#   (237, 2),
#   (246, 5),
#   (255, 5),
#   (256, 2),
#   (265, 1),
#   (269, 1),
#   (270, 9),
#   (271, 1),
#   (273, 1),
#   (274, 1),
#   (279, 1),
#   (281, 2),
#   (282, 149),
#   (287, 1),
#   (288, 3),
#   (289, 1),
#   (295, 1),
#   (296, 1),
#   (298, 5),
#   (299, 2),
#   (304, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (311, 8),
#   (317, 2),
#   (318, 1),
#   (319, 2),
#   (327, 1),
#   (330, 2),
#   (331, 3),
#   (337, 3),
#   (338, 3),
#   (341, 3),
#   (345, 2),
#   (359, 2),
#   (363, 1),
#   (364, 1),
#   (368, 3),
#   (370, 1),
#   (380, 10),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 3),
#   (387, 2),
#   (389, 8),
#   (394, 2),
#   (399, 1),
#   (401, 1),
#   (402, 21),
#   (403, 10),
#   (406, 2),
#   (407, 1),
#   (411, 2),
#   (412, 1),
#   (415, 2),
#   (419, 6),
#   (420, 2),
#   (421, 2),
#   (422, 4),
#   (427, 1),
#   (431, 2),
#   (432, 1),
#   (435, 7),
#   (437, 3),
#   (438, 1),
#   (443, 1),
#   (446, 1),
#   (450, 3),
#   (451, 1),
#   (458, 4),
#   (464, 1),
#   (468, 1),
#   (469, 1),
#   (474, 11),
#   (475, 15),
#   (486, 3),
#   (487, 5),
#   (488, 1),
#   (490, 1),
#   (491, 1),
#   (494, 2),
#   (495, 1),
#   (496, 1),
#   (499, 7),
#   (507, 1),
#   (508, 3),
#   (512, 2),
#   (513, 9),
#   (517, 1),
#   (522, 5),
#   (525, 1),
#   (526, 2),
#   (529, 10),
#   (533, 2),
#   (534, 1),
#   (536, 3),
#   (540, 2),
#   (542, 2),
#   (544, 2),
#   (545, 2),
#   (547, 4),
#   (549, 5),
#   (550, 1),
#   (558, 1),
#   (560, 1),
#   (565, 2),
#   (573, 5),
#   (574, 1),
#   (575, 3),
#   (576, 8),
#   (578, 2),
#   (579, 1),
#   (583, 1),
#   (588, 1),
#   (593, 2),
#   (594, 36),
#   (595, 2),
#   (598, 3),
#   (599, 3),
#   (606, 1),
#   (608, 37),
#   (609, 1),
#   (612, 6),
#   (614, 1),
#   (616, 1),
#   (619, 1),
#   (620, 2),
#   (622, 3),
#   (631, 1),
#   (636, 2),
#   (639, 1),
#   (646, 2),
#   (651, 3),
#   (654, 3),
#   (655, 8),
#   (656, 3),
#   (657, 1),
#   (661, 1),
#   (662, 22),
#   (667, 5),
#   (668, 1),
#   (671, 2),
#   (672, 1),
#   (673, 3),
#   (676, 1),
#   (677, 1),
#   (686, 1),
#   (687, 1),
#   (688, 22),
#   (691, 3),
#   (697, 5),
#   (707, 3),
#   (720, 9),
#   (721, 10),
#   (726, 1),
#   (727, 1),
#   (732, 1),
#   (738, 2),
#   (740, 14),
#   (741, 2),
#   (742, 1),
#   (752, 5),
#   (753, 1),
#   (757, 1),
#   (759, 2),
#   (762, 1),
#   (768, 3),
#   (769, 2),
#   (770, 2),
#   (771, 1),
#   (773, 1),
#   (780, 1),
#   (782, 1),
#   (785, 1),
#   (789, 1),
#   (791, 1),
#   (798, 1),
#   (799, 3),
#   (801, 1),
#   (810, 1),
#   (814, 1),
#   (818, 1),
#   (827, 1),
#   (828, 34),
#   (829, 33),
#   (830, 10),
#   (836, 5),
#   (837, 2),
#   (840, 8),
#   (841, 1),
#   (844, 6),
#   (845, 1),
#   (853, 2),
#   (857, 4),
#   (859, 1),
#   (860, 1),
#   (866, 1),
#   (868, 1),
#   (870, 8),
#   (881, 5),
#   (882, 1),
#   (884, 1),
#   (885, 1),
#   (888, 2),
#   (893, 1),
#   (895, 2),
#   (898, 1),
#   (900, 1),
#   (901, 1),
#   (903, 1),
#   (909, 1),
#   (910, 5),
#   (911, 3),
#   (912, 1),
#   (913, 1),
#   (915, 4),
#   (916, 1),
#   (925, 1),
#   (926, 1),
#   (931, 2),
#   (934, 1),
#   (941, 1),
#   (942, 2),
#   (943, 2),
#   (948, 1),
#   (950, 1),
#   (952, 1),
#   (953, 2),
#   (957, 2),
#   (965, 3),
#   (966, 1),
#   (967, 1),
#   (969, 6),
#   (971, 1),
#   (973, 1),
#   (975, 6),
#   (976, 1),
#   (991, 2),
#   (996, 2),
#   (997, 1),
#   (1006, 4),
#   (1010, 5),
#   (1014, 8),
#   (1015, 5),
#   (1016, 7),
#   (1018, 4),
#   (1019, 5),
#   (1020, 1),
#   (1022, 1),
#   (1024, 3),
#   (1027, 6),
#   (1031, 2),
#   (1038, 1),
#   (1039, 2),
#   (1041, 2),
#   (1044, 1),
#   (1046, 9),
#   (1047, 1),
#   (1052, 1),
#   (1056, 1),
#   (1061, 5),
#   (1062, 3),
#   (1063, 2),
#   (1066, 2),
#   (1075, 3),
#   (1078, 1),
#   (1080, 3),
#   (1083, 1),
#   (1084, 1),
#   (1085, 1),
#   (1086, 2),
#   (1087, 1),
#   (1088, 1),
#   (1089, 2),
#   (1097, 1),
#   (1104, 4),
#   (1106, 2),
#   (1108, 1),
#   (1109, 2),
#   (1111, 3),
#   (1112, 1),
#   (1113, 1),
#   (1115, 7),
#   (1120, 1),
#   (1121, 2),
#   (1128, 4),
#   (1135, 2),
#   (1138, 1),
#   (1141, 2),
#   (1144, 1),
#   (1159, 4),
#   (1164, 1),
#   (1166, 1),
#   (1167, 1),
#   (1168, 2),
#   (1171, 1),
#   (1172, 1),
#   (1173, 2),
#   (1181, 4),
#   (1182, 1),
#   (1183, 1),
#   (1186, 24),
#   (1193, 4),
#   (1195, 2),
#   (1200, 17),
#   (1202, 4),
#   (1203, 2),
#   (1205, 1),
#   (1206, 5),
#   (1213, 6),
#   (1226, 3),
#   (1227, 54),
#   (1228, 1),
#   (1229, 1),
#   (1230, 1),
#   (1232, 1),
#   (1233, 9),
#   (1234, 2),
#   (1235, 1),
#   (1253, 1),
#   (1256, 1),
#   (1267, 7),
#   (1269, 2),
#   (1278, 1),
#   (1330, 1),
#   (1337, 1),
#   (1343, 1),
#   (1358, 3),
#   (1359, 1),
#   (1363, 1),
#   (1366, 3),
#   (1372, 1),
#   (1382, 1),
#   (1383, 1),
#   (1389, 1),
#   (1390, 3),
#   (1393, 1),
#   (1418, 1),
#   (1430, 1),
#   (1433, 3),
#   (1435, 1),
#   (1445, 3),
#   (1446, 1),
#   (1476, 1),
#   (1498, 2),
#   (1500, 1),
#   (1511, 1),
#   (1530, 1),
#   (1531, 2),
#   (1539, 1),
#   (1550, 1),
#   (1553, 1),
#   (1561, 4),
#   (1576, 2),
#   (1580, 2),
#   (1588, 1),
#   (1604, 2),
#   (1610, 1),
#   (1616, 3),
#   (1617, 1),
#   (1637, 2),
#   (1644, 1),
#   (1672, 1),
#   (1679, 1),
#   (1687, 3),
#   (1704, 1),
#   (1718, 1),
#   (1724, 3),
#   (1750, 1),
#   (1757, 3),
#   (1759, 1),
#   (1770, 1),
#   (1772, 1),
#   (1773, 1),
#   (1774, 3),
#   (1783, 3),
#   (1804, 1),
#   (1806, 1),
#   (1815, 4),
#   (1824, 1),
#   (1825, 1),
#   (1834, 2),
#   (1836, 3),
#   (1839, 3),
#   (1841, 1),
#   (1853, 1),
#   (1865, 1),
#   (1870, 1),
#   (1878, 1),
#   (1880, 1),
#   (1887, 1),
#   (1888, 1),
#   (1895, 1),
#   (1898, 1),
#   (1922, 1),
#   (1927, 3),
#   (1937, 1),
#   (1944, 1),
#   (1945, 1),
#   (1976, 2),
#   (1980, 1),
#   (2000, 1),
#   (2011, 1),
#   (2035, 4),
#   (2049, 1),
#   (2058, 1),
#   (2059, 1),
#   (2070, 1),
#   (2102, 1),
#   (2104, 1),
#   (2111, 2),
#   (2122, 1),
#   (2129, 1),
#   (2140, 3),
#   (2180, 1),
#   (2188, 1),
#   (2191, 1),
#   (2195, 2),
#   (2200, 1),
#   (2215, 2),
#   (2217, 1),
#   (2225, 1),
#   (2228, 2),
#   (2233, 2),
#   (2249, 1),
#   (2286, 1),
#   (2290, 2),
#   (2294, 1),
#   (2295, 1),
#   (2302, 2),
#   (2329, 1),
#   (2354, 1),
#   (2371, 1),
#   (2382, 1),
#   (2388, 1),
#   (2409, 1),
#   (2422, 4),
#   (2442, 1),
#   (2444, 1),
#   (2450, 2),
#   (2452, 2),
#   (2465, 1),
#   (2471, 1),
#   (2473, 1),
#   (2479, 1),
#   (2490, 3),
#   (2491, 1),
#   (2493, 1),
#   (2500, 1),
#   (2507, 1),
#   (2509, 1),
#   (2545, 1),
#   (4796, 1),
#   (4797, 1),
#   (4798, 1),
#   (4799, 1),
#   (4800, 1),
#   (4801, 1),
#   (4802, 1),
#   (4803, 1),
#   (4804, 2),
#   (4805, 2),
#   (4806, 1),
#   (4807, 1),
#   (4808, 1),
#   (4809, 1),
#   (4810, 1),
#   (4811, 1),
#   (4812, 12),
#   (4813, 1),
#   (4814, 1),
#   (4815, 1),
#   (4816, 2),
#   (4817, 1),
#   (4818, 1),
#   (4819, 1),
#   (4820, 1),
#   (4821, 1),
#   (4822, 1),
#   (4823, 1),
#   (4824, 1),
#   (4825, 1),
#   (4826, 1),
#   (4827, 2),
#   (4828, 1),
#   (4829, 2),
#   (4830, 1),
#   (4831, 1),
#   (4832, 1),
#   (4833, 1),
#   (4834, 1),
#   (4835, 1),
#   (4836, 2),
#   (4837, 1),
#   (4838, 1),
#   (4839, 1),
#   (4840, 1),
#   (4841, 1),
#   (4842, 1),
#   (4843, 1),
#   (4844, 1),
#   (4845, 1),
#   (4846, 1),
#   (4847, 2),
#   (4848, 2),
#   (4849, 1),
#   (4850, 1),
#   (4851, 1),
#   (4852, 1),
#   (4853, 1),
#   (4854, 2),
#   (4855, 2),
#   (4856, 1),
#   (4857, 3),
#   (4858, 1),
#   (4859, 2),
#   (4860, 1),
#   (4861, 5),
#   (4862, 3),
#   (4863, 2),
#   (4864, 3),
#   (4865, 1),
#   (4866, 1),
#   (4867, 1),
#   (4868, 1),
#   (4869, 1),
#   (4870, 1),
#   (4871, 1),
#   (4872, 2),
#   (4873, 4),
#   (4874, 1),
#   (4875, 1),
#   (4876, 1),
#   (4877, 1),
#   (4878, 1),
#   (4879, 1),
#   (4880, 1),
#   (4881, 1),
#   ...],
#  [(2, 2),
#   (8, 3),
#   (9, 23),
#   (15, 1),
#   (17, 1),
#   (26, 3),
#   (35, 1),
#   (38, 2),
#   (40, 2),
#   (41, 2),
#   (42, 1),
#   (44, 1),
#   (46, 1),
#   (48, 2),
#   (49, 4),
#   (55, 3),
#   (61, 1),
#   (63, 1),
#   (64, 4),
#   (77, 1),
#   (88, 1),
#   (89, 2),
#   (113, 4),
#   (114, 2),
#   (115, 2),
#   (117, 2),
#   (125, 1),
#   (126, 2),
#   (134, 1),
#   (136, 1),
#   (141, 2),
#   (145, 1),
#   (151, 3),
#   (156, 2),
#   (171, 12),
#   (172, 16),
#   (173, 1),
#   (179, 4),
#   (188, 1),
#   (205, 1),
#   (213, 1),
#   (217, 11),
#   (219, 1),
#   (220, 6),
#   (221, 3),
#   (222, 7),
#   (223, 1),
#   (229, 1),
#   (231, 1),
#   (246, 3),
#   (248, 4),
#   (251, 1),
#   (258, 1),
#   (261, 1),
#   (262, 1),
#   (270, 20),
#   (271, 1),
#   (277, 4),
#   (278, 1),
#   (279, 3),
#   (280, 5),
#   (288, 1),
#   (289, 1),
#   (299, 1),
#   (317, 2),
#   (318, 2),
#   (320, 1),
#   (321, 1),
#   (323, 1),
#   (324, 1),
#   (326, 1),
#   (327, 2),
#   (330, 3),
#   (331, 1),
#   (337, 1),
#   (339, 5),
#   (341, 1),
#   (344, 2),
#   (348, 1),
#   (353, 1),
#   (366, 1),
#   (380, 1),
#   (382, 1),
#   (386, 2),
#   (387, 2),
#   (388, 1),
#   (389, 3),
#   (393, 1),
#   (395, 1),
#   (402, 1),
#   (414, 1),
#   (416, 1),
#   (422, 1),
#   (423, 1),
#   (427, 1),
#   (430, 3),
#   (431, 1),
#   (434, 2),
#   (435, 8),
#   (437, 1),
#   (450, 1),
#   (453, 2),
#   (458, 1),
#   (459, 1),
#   (490, 3),
#   (495, 1),
#   (496, 1),
#   (505, 15),
#   (507, 1),
#   (512, 2),
#   (513, 4),
#   (517, 1),
#   (519, 1),
#   (525, 1),
#   (537, 1),
#   (544, 1),
#   (545, 1),
#   (550, 1),
#   (554, 7),
#   (562, 1),
#   (565, 1),
#   (573, 5),
#   (575, 1),
#   (576, 1),
#   (578, 2),
#   (579, 3),
#   (580, 2),
#   (583, 2),
#   (585, 1),
#   (598, 1),
#   (599, 4),
#   (604, 1),
#   (606, 3),
#   (608, 2),
#   (612, 4),
#   (616, 1),
#   (619, 1),
#   (621, 1),
#   (636, 1),
#   (648, 1),
#   (651, 2),
#   (661, 2),
#   (662, 2),
#   (665, 1),
#   (666, 1),
#   (668, 1),
#   (673, 2),
#   (679, 9),
#   (685, 9),
#   (686, 21),
#   (691, 3),
#   (700, 1),
#   (707, 8),
#   (713, 2),
#   (720, 2),
#   (721, 1),
#   (724, 1),
#   (725, 1),
#   (726, 1),
#   (740, 2),
#   (741, 1),
#   (745, 1),
#   (747, 3),
#   (757, 1),
#   (770, 4),
#   (776, 1),
#   (788, 1),
#   (792, 5),
#   (793, 3),
#   (801, 4),
#   (802, 1),
#   (807, 1),
#   (814, 2),
#   (818, 7),
#   (836, 2),
#   (842, 1),
#   (845, 1),
#   (855, 1),
#   (860, 1),
#   (866, 1),
#   (867, 4),
#   (868, 1),
#   (874, 1),
#   (879, 1),
#   (882, 1),
#   (883, 1),
#   (885, 3),
#   (892, 1),
#   (893, 1),
#   (900, 2),
#   (903, 1),
#   (906, 1),
#   (909, 2),
#   (910, 5),
#   (912, 1),
#   (915, 1),
#   (916, 1),
#   (922, 1),
#   (926, 1),
#   (928, 3),
#   (929, 1),
#   (930, 1),
#   (931, 3),
#   (941, 1),
#   (942, 2),
#   (949, 1),
#   (959, 12),
#   (962, 1),
#   (966, 1),
#   (969, 1),
#   (975, 1),
#   (1009, 1),
#   (1019, 2),
#   (1024, 1),
#   (1027, 3),
#   (1034, 1),
#   (1041, 3),
#   (1043, 23),
#   (1044, 2),
#   (1046, 2),
#   (1047, 1),
#   (1056, 4),
#   (1061, 3),
#   (1066, 2),
#   (1069, 2),
#   (1073, 1),
#   (1080, 20),
#   (1082, 1),
#   (1089, 1),
#   (1111, 1),
#   (1117, 2),
#   (1127, 1),
#   (1136, 1),
#   (1138, 17),
#   (1144, 1),
#   (1154, 1),
#   (1155, 1),
#   (1159, 1),
#   (1172, 1),
#   (1175, 1),
#   (1176, 1),
#   (1182, 1),
#   (1183, 1),
#   (1190, 2),
#   (1191, 2),
#   (1193, 4),
#   (1196, 1),
#   (1200, 6),
#   (1206, 4),
#   (1218, 1),
#   (1223, 2),
#   (1225, 1),
#   (1226, 1),
#   (1228, 1),
#   (1229, 3),
#   (1233, 4),
#   (1234, 5),
#   (1248, 2),
#   (1251, 1),
#   (1253, 3),
#   (1255, 2),
#   (1256, 1),
#   (1267, 1),
#   (1269, 4),
#   (1278, 8),
#   (1280, 1),
#   (1283, 3),
#   (1295, 1),
#   (1296, 2),
#   (1305, 2),
#   (1323, 1),
#   (1336, 1),
#   (1390, 2),
#   (1391, 1),
#   (1396, 1),
#   (1411, 1),
#   (1415, 2),
#   (1417, 2),
#   (1424, 11),
#   (1432, 1),
#   (1436, 4),
#   (1444, 1),
#   (1445, 1),
#   (1462, 1),
#   (1467, 1),
#   (1474, 1),
#   (1482, 5),
#   (1486, 8),
#   (1487, 2),
#   (1488, 18),
#   (1519, 1),
#   (1521, 6),
#   (1523, 24),
#   (1530, 1),
#   (1531, 2),
#   (1545, 1),
#   (1546, 6),
#   (1550, 1),
#   (1560, 2),
#   (1561, 1),
#   (1576, 1),
#   (1581, 23),
#   (1583, 1),
#   (1589, 1),
#   (1591, 1),
#   (1616, 1),
#   (1620, 3),
#   (1622, 7),
#   (1623, 2),
#   (1633, 1),
#   (1637, 1),
#   (1646, 1),
#   (1661, 2),
#   (1672, 1),
#   (1675, 1),
#   (1677, 1),
#   (1678, 1),
#   (1681, 1),
#   (1687, 2),
#   (1695, 1),
#   (1700, 2),
#   (1707, 19),
#   (1718, 4),
#   (1719, 1),
#   (1724, 2),
#   (1759, 3),
#   (1772, 1),
#   (1774, 2),
#   (1778, 2),
#   (1790, 8),
#   (1794, 1),
#   (1825, 1),
#   (1828, 2),
#   (1829, 5),
#   (1832, 1),
#   (1834, 1),
#   (1835, 2),
#   (1841, 2),
#   (1865, 1),
#   (1869, 1),
#   (1877, 1),
#   (1878, 1),
#   (1880, 6),
#   (1881, 3),
#   (1884, 2),
#   (1892, 3),
#   (1898, 1),
#   (1913, 1),
#   (1919, 1),
#   (1920, 6),
#   (1925, 1),
#   (1935, 2),
#   (1938, 1),
#   (1940, 1),
#   (1945, 1),
#   (1960, 1),
#   (1972, 1),
#   (1975, 5),
#   (1976, 1),
#   (1980, 3),
#   (1983, 2),
#   (2009, 3),
#   (2044, 6),
#   (2102, 1),
#   (2104, 1),
#   (2111, 1),
#   (2131, 1),
#   (2158, 2),
#   (2159, 1),
#   (2173, 1),
#   (2180, 1),
#   (2187, 1),
#   (2190, 3),
#   (2191, 1),
#   (2196, 1),
#   (2212, 1),
#   (2213, 1),
#   (2215, 1),
#   (2222, 1),
#   (2227, 1),
#   (2238, 4),
#   (2248, 5),
#   (2264, 1),
#   (2281, 1),
#   (2301, 1),
#   (2302, 20),
#   (2303, 1),
#   (2307, 1),
#   (2354, 2),
#   (2364, 1),
#   (2374, 3),
#   (2381, 12),
#   (2392, 2),
#   (2397, 1),
#   (2417, 2),
#   (2418, 1),
#   (2426, 5),
lda_model = gensim.models.ldamodel.LdaModel(input_corpus,num_topics=5,id2word=input_dict,passes=25)

# %%
topics = lda_model.print_topics(num_words=10)
topics
# Out:
# [(0,
#   '0.016*"animal" + 0.012*"astronomy" + 0.007*"geology" + 0.007*"geological" + 0.006*"galaxy" + 0.006*"planet" + 0.004*"object" + 0.004*"system" + 0.004*"observation" + 0.004*"formation"'),
#  (1,
#   '0.000*"animal" + 0.000*"system" + 0.000*"astronomy" + 0.000*"currency" + 0.000*"include" + 0.000*"medium" + 0.000*"government" + 0.000*"called" + 0.000*"theory" + 0.000*"geological"'),
#  (2,
#   '0.000*"political" + 0.000*"animal" + 0.000*"baseball" + 0.000*"politics" + 0.000*"system" + 0.000*"cricket" + 0.000*"player" + 0.000*"include" + 0.000*"league" + 0.000*"batter"'),
#  (3,
#   '0.016*"political" + 0.010*"system" + 0.008*"neuroscience" + 0.007*"politics" + 0.006*"society" + 0.006*"production" + 0.005*"neuron" + 0.004*"theory" + 0.004*"picture" + 0.004*"example"'),
#  (4,
#   '0.019*"baseball" + 0.017*"cricket" + 0.015*"batter" + 0.012*"player" + 0.012*"league" + 0.008*"inning" + 0.006*"wicket" + 0.006*"batting" + 0.006*"played" + 0.006*"pitcher"')]

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, input_corpus, dictionary=lda_model.id2word)
vis
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.175023 -0.077704       1        1  36.701178
# 3      0.003654  0.156960       2        1  32.295234
# 0     -0.160574 -0.081236       3        1  30.986636
# 2     -0.009025  0.001007       4        1   0.008476
# 1     -0.009079  0.000974       5        1   0.008476, topic_info=           Term        Freq       Total Category  logprob  loglift
# 100    baseball  147.000000  147.000000  Default  30.0000  30.0000
# 282     cricket  136.000000  136.000000  Default  29.0000  29.0000
# 109      batter  120.000000  120.000000  Default  28.0000  28.0000
# 3244     animal  109.000000  109.000000  Default  27.0000  27.0000
# 1794  political  108.000000  108.000000  Default  26.0000  26.0000
# ...         ...         ...         ...      ...      ...      ...
# 2316     galaxy    0.000333   41.709139   Topic5  -8.5969  -2.3638
# 2326    geology    0.000332   44.283253   Topic5  -8.5971  -2.4239
# 505    function    0.000332   28.362203   Topic5  -8.5971  -1.9783
# 1080   standard    0.000332   25.917360   Topic5  -8.5973  -1.8884
# 3621     specie    0.000332   27.239930   Topic5  -8.5975  -1.9383
#
# [346 rows x 6 columns], token_table=      Topic      Freq             Term
# term
# 9         1  0.901330          account
# 9         2  0.042920          account
# 9         3  0.042920          account
# 13        1  0.168314           action
# 13        2  0.841569           action
# ...     ...       ...              ...
# 1233      2  0.301803           within
# 1233      3  0.388033           within
# 2033      2  0.723384          woodrow
# 3681      3  0.725982  xenacoelomorpha
# 3687      3  0.725974         zoophyte
#
# [351 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 4, 1, 3, 2])

# %%
text = 'Every player will have their one bad game of a season. '
text = preprocess_text(text)
text = input_dict.doc2bow(text)
lda_model.get_document_topics(textt
# Out:
# [(0, 0.06682508),
#  (1, 0.066673234),
#  (2, 0.06667328),
#  (3, 0.06667018),
#  (4, 0.73315823)]
